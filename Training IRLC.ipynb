# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
# os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# %%
import torch
from torch.autograd import Variable

from dataset import Dictionary, HMQAFeatureDataset
from model import SoftCount
from config import *
from datetime import datetime, timedelta

import h5py
import numpy as np
import _pickle as pkl
import json
import torch.nn.functional as F

# %%
dictionary = Dictionary.load_from_file('data/dictionary.pkl')
# Out:
# loading dictionary from data/dictionary.pkl

# %%
# %%time
print('loading features from train hdf5 file')
train_h5_loc = './data/train36.hdf5'
with h5py.File(train_h5_loc, 'r') as hf:
    train_image_features = np.array(hf.get('image_features'))
    train_spatials_features = np.array(hf.get('spatial_features'))
# np.save( open("/tmp/vqa/train_image_features", "wb"), train_image_features)
# np.save( open("/tmp/vqa/train_spatials_features", "wb"), train_spatials_features)

# %%
# %%time
# train_image_features = np.load(open("/tmp/vqa/train_image_features", "rb"))
# train_spatials_features = np.load(open("/tmp/vqa/train_spatials_features", "rb"))
# Out:
# CPU times: user 92 ms, sys: 42.6 s, total: 42.7 s
# Wall time: 7min 15s

# %%
from dataset import HMQAFeatureDataset

hmqa_train_dset = HMQAFeatureDataset(
    img_id2hqma_idx = pkl.load(open("./data/train36_imgid2idx.pkl", "rb")),
    image_features = train_image_features, 
    spatial_features = train_spatials_features, 
    qid2count = json.load(open("./data/how_many_qa/qid2count.json", "rb")), 
    qid2count2score = json.load(open("./data/how_many_qa/qid2count2score.json", "rb")), 
    name="train", 
    dictionary=dictionary
)
del HMQAFeatureDataset

# %%
len(hmqa_train_dset)
# Out:
# 83642

# %%
len(set([x["image_id"] for x in hmqa_train_dset.entries]))
# Out:
# 45546

# %%
# %%time
print('loading features from val hdf5 file')
val_h5_loc = './data/val36.hdf5'
with h5py.File(val_h5_loc, 'r') as hf:
    val_image_features = np.array(hf.get('image_features'))
    val_spatials_features = np.array(hf.get('spatial_features'))
# np.save( open("/tmp/vqa/val_image_features", "wb"), val_image_features)
# np.save( open("/tmp/vqa/val_spatials_features", "wb"), val_spatials_features)

# %%
# %%time
# val_image_features = np.load(open("/tmp/vqa/val_image_features", "rb"))
# val_spatials_features = np.load(open("/tmp/vqa/val_spatials_features", "rb"))
# Out:
# CPU times: user 24 ms, sys: 24.1 s, total: 24.1 s
# Wall time: 1min 44s

# %%
# len(train_image_features)

from dataset import HMQAFeatureDataset

hmqa_dev_dset = HMQAFeatureDataset(
    img_id2hqma_idx = pkl.load(open("./data/val36_imgid2idx.pkl", "rb")),
    image_features = val_image_features, 
    spatial_features = val_spatials_features, 
    qid2count = json.load(open("./data/how_many_qa/qid2count.json", "rb")), 
    qid2count2score = json.load(open("./data/how_many_qa/qid2count2score.json", "rb")), 
    name="dev", 
    dictionary=dictionary
)

hmqa_test_dset = HMQAFeatureDataset(
    img_id2hqma_idx = pkl.load(open("./data/val36_imgid2idx.pkl", "rb")),
    image_features = val_image_features, 
    spatial_features = val_spatials_features, 
    qid2count = json.load(open("./data/how_many_qa/qid2count.json", "rb")), 
    qid2count2score = json.load(open("./data/how_many_qa/qid2count2score.json", "rb")), 
    name="test", 
    dictionary=dictionary
)
del HMQAFeatureDataset

# %%
len(hmqa_dev_dset), len(hmqa_test_dset)
# Out:
# (17714, 5000)

# %%
from torch.utils.data import DataLoader

hmqa_train_loader = DataLoader(hmqa_train_dset, 64, shuffle=True, num_workers=0)
hmqa_dev_loader = DataLoader(hmqa_dev_dset, 64, shuffle=True, num_workers=0)
hmqa_test_loader = DataLoader(hmqa_test_dset, 64, shuffle=True, num_workers=0)

# %%
def evaluate(model, hmqa_loader):
    
    all_acc = []
    all_se = []
    for i, (v_emb, b, q, c, c2s) in enumerate(hmqa_loader):
        v_emb = Variable(v_emb)
        b = Variable(b)
        q = Variable(q)
        c = Variable(c).view(-1).float()
        
        if USE_CUDA:
            v_emb = v_emb.cuda()
            b = b.cuda()
            q = q.cuda()
            c = c.cuda()
        
        kappa_0, rho = model.compute_vars(v_emb, b, q)
        count, greedy_count, logPA, entP, A, rho, P = model.take_mc_samples(kappa_0, rho, 1)
        
#         pred = model(v_emb, q)
        
#         ret = torch.stack((count.float(), greedy_count.float(), c.float()))
#         break
    
        nearest_pred = (greedy_count + 0.5).long().clamp(0, 20)
        for one_c, one_c2s, one_pred in zip(c, c2s, nearest_pred):
            one_c = one_c.cpu().data
            one_pred = one_pred.cpu().data
            
#             print("one_c = ", one_c, " and nearest pred = ", one_pred)
            
            all_se.append((one_c - one_pred.float()) ** 2)
            all_acc.append(one_c2s[one_pred])
    
    acc = torch.stack(all_acc).mean()
    rmse = torch.stack(all_se).mean() ** 0.5
    
    return acc, rmse  #, ret

# %%
def isnan(x):
    check = (x != x)
    check = check.float().sum().data[0]
    return check > 0

# %%
from model import IRLC
model = IRLC(dropout=0.5)
del IRLC
# Out:
# question parser has zero dropout
# initialising with glove embeddings
# done.

# %%
if USE_CUDA:
    model.cuda()
model
# Out:
# IRLC(
#   (ques_parser): QuestionParser(
#     (embd): Embedding(20159, 300, padding_idx=20158)
#     (rnn): GRU(300, 1024)
#     (drop): Dropout(p=0)
#   )
#   (f_s): ScoringFunction(
#     (v_drop): Dropout(p=0.5)
#     (q_drop): Dropout(p=0.5)
#     (v_proj): FCNet(
#       (main): Sequential(
#         (0): Linear(in_features=2048, out_features=2048, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#       )
#     )
#     (q_proj): FCNet(
#       (main): Sequential(
#         (0): Linear(in_features=1024, out_features=2048, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#       )
#     )
#     (s_drop): Dropout(p=0.5)
#   )
#   (W): Linear(in_features=2048, out_features=1, bias=True)
#   (f_rho): RhoScorer(
#     (W): Linear(in_features=1024, out_features=1, bias=True)
#     (f_rho): FCNet(
#       (main): Sequential(
#         (0): Linear(in_features=17, out_features=100, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#       )
#     )
#     (dense): Linear(in_features=100, out_features=1, bias=True)
#   )
#   (extra_params): ParameterList(
#       (0): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#   )
# )

# %%
test_acc, test_rmse = evaluate(model, hmqa_test_loader)
test_acc, test_rmse
# Out:
# (tensor(1.00000e-02 *
#         1.2440), tensor(17.4335))

# %%
opt = torch.optim.Adam(model.parameters(), lr=5e-4)
sched = torch.optim.lr_scheduler.ExponentialLR(opt, gamma=.99)

# %%
test_accs = []
test_rmses = []

dev_accs = []
dev_rmses = []

# %%
exp_name = "hope-2048-0.5-ques0"

# %%
for epoch in range(0, 100):
    # adjust learning rate
    sched.step()
    print("learning rate is {}".format(opt.param_groups[0]["lr"]))
    
    # save model every 10 epochs
    if epoch % 10 == 0:
        print("saving model..")
        torch.save(model.state_dict(), "./saved_models/{}-epoch-{}-acc-{}".format(exp_name, epoch, test_acc))
        print("Done.")
    
    for i, (v_emb, b, q, c, _) in enumerate(hmqa_train_loader):
        v_emb = Variable(v_emb)
        b = Variable(b)
        q = Variable(q)
        c = Variable(c).view(-1).float()

        if USE_CUDA:
            v_emb = v_emb.cuda()
            q = q.cuda()
            c = c.cuda()
            b = b.cuda()

        B, k, _ = v_emb.size()

        kappa_0, rho = model.compute_vars(v_emb, b, q)
        if isnan(kappa_0) or isnan(rho) or isnan(model.eps):
            raise Exception("there are nans here")

        num_samples = 32
        count, greedy_count, logPA, entP, A, rho, P = model.take_mc_samples(kappa_0, rho, num_samples)
        c_gt = torch.cat([c] * num_samples)

        loss = model.get_loss(c_gt, count, greedy_count, logPA, entP, A, rho)

        if i % 100 == 0:
            print("epoch = {}, i = {}, loss = {},".format(epoch, i, loss.data[0],))

        opt.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm(model.parameters(), 0.25)
        opt.step()


    print("evaluating model on dev and test...")

    model.eval()
    dev_acc, dev_rmse = evaluate(model, hmqa_dev_loader)
    print("dev_acc: {}, dev_rmse: {}".format(dev_acc, dev_rmse))
    test_acc, test_rmse = evaluate(model, hmqa_test_loader)
    print("test_acc: {}, test_rmse: {}".format(test_acc, test_rmse))
    model.train()
    
    test_accs.append(test_acc)
    test_rmses.append(test_rmse)
    dev_accs.append(dev_acc)
    dev_rmses.append(dev_rmse)
# Out:
# learning rate is 0.0005
# saving model..
# Done.
# /home/sanyam/miniconda3/envs/py3t4/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/sanyam/miniconda3/envs/py3t4/lib/python3.6/site-packages/ipykernel_launcher.py:37: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# /home/sanyam/miniconda3/envs/py3t4/lib/python3.6/site-packages/ipykernel_launcher.py:41: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
# epoch = 0, i = 0, loss = 30.2487850189209,
# epoch = 0, i = 100, loss = -0.024106265977025032,
# epoch = 0, i = 200, loss = 0.017748812213540077,
# epoch = 0, i = 300, loss = 0.062310248613357544,
# epoch = 0, i = 400, loss = -0.05417848378419876,
# epoch = 0, i = 500, loss = 0.0579473152756691,
# epoch = 0, i = 600, loss = 0.04424819350242615,
# epoch = 0, i = 700, loss = -0.005923263728618622,
# epoch = 0, i = 800, loss = -0.13275228440761566,
# epoch = 0, i = 900, loss = -0.0817226842045784,
# epoch = 0, i = 1000, loss = -0.09168244898319244,
# epoch = 0, i = 1100, loss = 0.008359390310943127,
# epoch = 0, i = 1200, loss = -0.026331951841711998,
# epoch = 0, i = 1300, loss = -0.06636011600494385,
# evaluating model on dev and test...
# dev_acc: 0.38167551159858704, dev_rmse: 3.376408576965332
# test_acc: 0.3896600008010864, test_rmse: 3.150238037109375
# learning rate is 0.000495
# epoch = 1, i = 0, loss = -0.05858936905860901,
# epoch = 1, i = 100, loss = -0.07893369346857071,
# epoch = 1, i = 200, loss = -0.11728308349847794,
# epoch = 1, i = 300, loss = -0.16926924884319305,
# epoch = 1, i = 400, loss = -0.05689196288585663,
# epoch = 1, i = 500, loss = -0.06467311084270477,
# epoch = 1, i = 600, loss = -0.12108361721038818,
# epoch = 1, i = 700, loss = 0.0012465119361877441,
# epoch = 1, i = 800, loss = -0.13119015097618103,
# epoch = 1, i = 900, loss = -0.013724343851208687,
# epoch = 1, i = 1000, loss = -0.278865247964859,
# epoch = 1, i = 1100, loss = 0.03510097786784172,
# epoch = 1, i = 1200, loss = 0.022461486980319023,
# epoch = 1, i = 1300, loss = 0.01468845084309578,
# evaluating model on dev and test...
# dev_acc: 0.42459070682525635, dev_rmse: 3.0427777767181396
# test_acc: 0.4223400056362152, test_rmse: 2.76239013671875
# learning rate is 0.00049005
# epoch = 2, i = 0, loss = -0.015051200985908508,
# epoch = 2, i = 100, loss = -0.06662872433662415,
# epoch = 2, i = 200, loss = -0.003172263503074646,
# epoch = 2, i = 300, loss = -0.06883039325475693,
# epoch = 2, i = 400, loss = -0.043078918009996414,
# epoch = 2, i = 500, loss = -0.036310188472270966,
# epoch = 2, i = 600, loss = -0.04838031530380249,
# epoch = 2, i = 700, loss = -0.014637021347880363,
# epoch = 2, i = 800, loss = -0.011630818247795105,
# epoch = 2, i = 900, loss = -0.052004631608724594,
# epoch = 2, i = 1000, loss = -0.0886460393667221,
# epoch = 2, i = 1100, loss = -0.03892316669225693,
# epoch = 2, i = 1200, loss = -0.07864585518836975,
# epoch = 2, i = 1300, loss = 0.007510642521083355,
# evaluating model on dev and test...
# dev_acc: 0.43553686141967773, dev_rmse: 2.9828269481658936
# test_acc: 0.4343400001525879, test_rmse: 2.7035531997680664
# learning rate is 0.00048514950000000005
# epoch = 3, i = 0, loss = 0.05881839990615845,
# epoch = 3, i = 100, loss = -0.047312960028648376,
# epoch = 3, i = 200, loss = -0.03558856621384621,
# epoch = 3, i = 300, loss = -0.040671125054359436,
# epoch = 3, i = 400, loss = -0.02478852868080139,
# epoch = 3, i = 500, loss = 0.029772676527500153,
# epoch = 3, i = 600, loss = -0.05832381546497345,
# epoch = 3, i = 700, loss = -0.025981931015849113,
# epoch = 3, i = 800, loss = -0.09457510709762573,
# epoch = 3, i = 900, loss = -0.00876215472817421,
# epoch = 3, i = 1000, loss = 0.00785657949745655,
# epoch = 3, i = 1100, loss = -0.07524561882019043,
# epoch = 3, i = 1200, loss = -0.06122957542538643,
# epoch = 3, i = 1300, loss = -0.014232035726308823,
# evaluating model on dev and test...
# dev_acc: 0.44481199979782104, dev_rmse: 2.983640670776367
# test_acc: 0.44387999176979065, test_rmse: 2.7093911170959473
# learning rate is 0.00048029800499999997
# epoch = 4, i = 0, loss = -0.07387708872556686,
# epoch = 4, i = 100, loss = 0.014906886965036392,
# epoch = 4, i = 200, loss = -0.0315302237868309,
# epoch = 4, i = 300, loss = 0.012537405826151371,
# epoch = 4, i = 400, loss = -0.02851187065243721,
# epoch = 4, i = 500, loss = 0.01060375664383173,
# epoch = 4, i = 600, loss = -0.06588880717754364,
# epoch = 4, i = 700, loss = -0.03964035585522652,
# epoch = 4, i = 800, loss = -0.1147146001458168,
# epoch = 4, i = 900, loss = -0.014682089909911156,
# epoch = 4, i = 1000, loss = 0.02352622151374817,
# epoch = 4, i = 1100, loss = -0.039927247911691666,
# epoch = 4, i = 1200, loss = -0.04930980131030083,
# epoch = 4, i = 1300, loss = -0.03478457033634186,
# evaluating model on dev and test...
# dev_acc: 0.46560347080230713, dev_rmse: 2.883976459503174
# test_acc: 0.4710800051689148, test_rmse: 2.586580753326416
# learning rate is 0.00047549502494999995
# epoch = 5, i = 0, loss = -0.06629254668951035,
# epoch = 5, i = 100, loss = -0.023450519889593124,
# epoch = 5, i = 200, loss = -0.02563561126589775,
# epoch = 5, i = 300, loss = -0.03373283892869949,
# epoch = 5, i = 400, loss = -0.06562617421150208,
# epoch = 5, i = 500, loss = -0.005508227273821831,
# epoch = 5, i = 600, loss = 0.00678503792732954,
# epoch = 5, i = 700, loss = -0.10686048865318298,
# epoch = 5, i = 800, loss = -0.025162098929286003,
# epoch = 5, i = 900, loss = -0.023193737491965294,
# epoch = 5, i = 1000, loss = -0.05757501348853111,
# epoch = 5, i = 1100, loss = 0.004463654011487961,
# epoch = 5, i = 1200, loss = -0.07394976168870926,
# epoch = 5, i = 1300, loss = -0.050552964210510254,
# evaluating model on dev and test...
# dev_acc: 0.4731963574886322, dev_rmse: 2.8545525074005127
# test_acc: 0.48476001620292664, test_rmse: 2.586232900619507
# learning rate is 0.0004707400747005
# epoch = 6, i = 0, loss = 0.008890875615179539,
# epoch = 6, i = 100, loss = 0.009267093613743782,
# epoch = 6, i = 200, loss = -0.035359639674425125,
# epoch = 6, i = 300, loss = -0.02069137431681156,
# epoch = 6, i = 400, loss = -0.06501470506191254,
# epoch = 6, i = 500, loss = -0.025206806138157845,
# epoch = 6, i = 600, loss = -0.04636279493570328,
# epoch = 6, i = 700, loss = 0.005320755764842033,
# epoch = 6, i = 800, loss = 0.01240449957549572,
# epoch = 6, i = 900, loss = -0.029577268287539482,
# epoch = 6, i = 1000, loss = -0.018446289002895355,
# epoch = 6, i = 1100, loss = -0.04751311242580414,
# epoch = 6, i = 1200, loss = -0.13094621896743774,
# epoch = 6, i = 1300, loss = 0.00132749043405056,
# evaluating model on dev and test...
# dev_acc: 0.4770859181880951, dev_rmse: 2.8360512256622314
# test_acc: 0.49362000823020935, test_rmse: 2.564761161804199
# learning rate is 0.00046603267395349497
# epoch = 7, i = 0, loss = -0.046673573553562164,
# epoch = 7, i = 100, loss = -0.052860114723443985,
# epoch = 7, i = 200, loss = -0.06861180812120438,
# epoch = 7, i = 300, loss = -0.006859485059976578,
# epoch = 7, i = 400, loss = -0.012724993750452995,
# epoch = 7, i = 500, loss = -0.06206054612994194,
# epoch = 7, i = 600, loss = -0.06298685818910599,
# epoch = 7, i = 700, loss = 0.004318153485655785,
# epoch = 7, i = 800, loss = -0.02040131576359272,
# epoch = 7, i = 900, loss = -0.01291365921497345,
# epoch = 7, i = 1000, loss = -0.029648801311850548,
# epoch = 7, i = 1100, loss = 0.00813982356339693,
# epoch = 7, i = 1200, loss = -0.07444975525140762,
# epoch = 7, i = 1300, loss = -0.03048410825431347,
# evaluating model on dev and test...
# dev_acc: 0.48370781540870667, dev_rmse: 2.8653299808502197
# test_acc: 0.4968400001525879, test_rmse: 2.6148040294647217
# learning rate is 0.00046137234721396004
# epoch = 8, i = 0, loss = -0.06019636616110802,
# epoch = 8, i = 100, loss = -0.04020293056964874,
# epoch = 8, i = 200, loss = -0.006390247493982315,
# epoch = 8, i = 300, loss = -0.07140030711889267,
# epoch = 8, i = 400, loss = -0.0006813649088144302,
# epoch = 8, i = 500, loss = -0.07067384570837021,
# epoch = 8, i = 600, loss = -0.04735638201236725,
# epoch = 8, i = 700, loss = 0.005355291999876499,
# epoch = 8, i = 800, loss = -0.011314930394291878,
# epoch = 8, i = 900, loss = -0.08106144517660141,
# epoch = 8, i = 1000, loss = -0.06727924942970276,
# epoch = 8, i = 1100, loss = -0.006785402074456215,
# epoch = 8, i = 1200, loss = -0.054008014500141144,
# epoch = 8, i = 1300, loss = 0.010041475296020508,
# evaluating model on dev and test...
# dev_acc: 0.48719093203544617, dev_rmse: 2.797713279724121
# test_acc: 0.49862000346183777, test_rmse: 2.525391101837158
# learning rate is 0.00045675862374182043
# epoch = 9, i = 0, loss = -0.0361483171582222,
# epoch = 9, i = 100, loss = -0.025727149099111557,
# epoch = 9, i = 200, loss = -0.10432140529155731,
# epoch = 9, i = 300, loss = -0.0375729501247406,
# epoch = 9, i = 400, loss = -0.05646316707134247,
# epoch = 9, i = 500, loss = 0.03468010574579239,
# epoch = 9, i = 600, loss = 0.0030097588896751404,
# epoch = 9, i = 700, loss = -0.009353281930088997,
# epoch = 9, i = 800, loss = -0.06197524070739746,
# epoch = 9, i = 900, loss = -0.09363559633493423,
# epoch = 9, i = 1000, loss = -0.051551178097724915,
# epoch = 9, i = 1100, loss = 0.0009079091250896454,
# epoch = 9, i = 1200, loss = -0.008880775421857834,
# epoch = 9, i = 1300, loss = -0.0353664755821228,
# evaluating model on dev and test...
# dev_acc: 0.4946313798427582, dev_rmse: 2.7893266677856445
# test_acc: 0.4986400008201599, test_rmse: 2.530019760131836
# learning rate is 0.0004521910375044022
# saving model..
# Done.
# epoch = 10, i = 0, loss = -0.04381684958934784,
# epoch = 10, i = 100, loss = -0.013822140172123909,
# epoch = 10, i = 200, loss = -0.04546855390071869,
# epoch = 10, i = 300, loss = -0.02390332706272602,
# epoch = 10, i = 400, loss = -0.058667588979005814,
# epoch = 10, i = 500, loss = -0.04164177179336548,
# epoch = 10, i = 600, loss = -0.10120292752981186,
# epoch = 10, i = 700, loss = -0.03419499844312668,
# epoch = 10, i = 800, loss = 0.03150828927755356,
# epoch = 10, i = 900, loss = -0.0032899100333452225,
# epoch = 10, i = 1000, loss = -0.06014528125524521,
# epoch = 10, i = 1100, loss = 0.009419145062565804,
# epoch = 10, i = 1200, loss = 0.009027520194649696,
# epoch = 10, i = 1300, loss = -0.054855018854141235,
# evaluating model on dev and test...
# dev_acc: 0.49156033992767334, dev_rmse: 2.837364673614502
# test_acc: 0.5081599950790405, test_rmse: 2.5715365409851074
# learning rate is 0.0004476691271293582
# epoch = 11, i = 0, loss = -0.015603138133883476,
# epoch = 11, i = 100, loss = -0.0455997958779335,
# epoch = 11, i = 200, loss = -0.013598024845123291,
# epoch = 11, i = 300, loss = -0.031307756900787354,
# epoch = 11, i = 400, loss = -0.0369311198592186,
# epoch = 11, i = 500, loss = 0.016180019825696945,
# epoch = 11, i = 600, loss = 0.0011669080704450607,
# epoch = 11, i = 700, loss = -0.042901597917079926,
# epoch = 11, i = 800, loss = -0.005257365293800831,
# epoch = 11, i = 900, loss = -0.042866550385951996,
# epoch = 11, i = 1000, loss = 0.008255385793745518,
# epoch = 11, i = 1100, loss = -0.04455060884356499,
# epoch = 11, i = 1200, loss = 0.01058756373822689,
# epoch = 11, i = 1300, loss = 0.006568284705281258,
# evaluating model on dev and test...
# dev_acc: 0.4933781325817108, dev_rmse: 2.756211757659912
# test_acc: 0.5090000033378601, test_rmse: 2.5431084632873535
# learning rate is 0.0004431924358580646
# epoch = 12, i = 0, loss = -0.022812308743596077,
# epoch = 12, i = 100, loss = -0.016826573759317398,
# epoch = 12, i = 200, loss = -0.0374799482524395,
# epoch = 12, i = 300, loss = -0.04566557705402374,
# epoch = 12, i = 400, loss = -0.05645626783370972,
# epoch = 12, i = 500, loss = 0.001542564481496811,
# epoch = 12, i = 600, loss = -0.02850925363600254,
# epoch = 12, i = 700, loss = -0.001630447804927826,
# epoch = 12, i = 800, loss = 0.027319779619574547,
# epoch = 12, i = 900, loss = -0.020323826000094414,
# epoch = 12, i = 1000, loss = -0.03497328609228134,
# epoch = 12, i = 1100, loss = -0.007286811247467995,
# epoch = 12, i = 1200, loss = -0.03444068878889084,
# epoch = 12, i = 1300, loss = -0.056494832038879395,
# evaluating model on dev and test...
# dev_acc: 0.5042000412940979, dev_rmse: 2.7585151195526123
# test_acc: 0.5179399847984314, test_rmse: 2.521507501602173
# learning rate is 0.00043876051149948394
# epoch = 13, i = 0, loss = -0.02190464362502098,
# epoch = 13, i = 100, loss = -0.047250572592020035,
# epoch = 13, i = 200, loss = -0.02975057065486908,
# epoch = 13, i = 300, loss = -0.03134515881538391,
# epoch = 13, i = 400, loss = -0.006402729079127312,
# epoch = 13, i = 500, loss = 0.0013484787195920944,
# epoch = 13, i = 600, loss = 0.011975736357271671,
# epoch = 13, i = 700, loss = -0.01999746263027191,
# epoch = 13, i = 800, loss = -0.05090288072824478,
# epoch = 13, i = 900, loss = -0.07772669196128845,
# epoch = 13, i = 1000, loss = -0.010447023436427116,
# epoch = 13, i = 1100, loss = -0.08677083998918533,
# epoch = 13, i = 1200, loss = -0.06768409162759781,
# epoch = 13, i = 1300, loss = -0.03912952542304993,
# evaluating model on dev and test...
# dev_acc: 0.5026927590370178, dev_rmse: 2.7801637649536133
# test_acc: 0.5204399824142456, test_rmse: 2.5306124687194824
# learning rate is 0.00043437290638448915
# epoch = 14, i = 0, loss = -0.011164413765072823,
# epoch = 14, i = 100, loss = -0.04972896724939346,
# epoch = 14, i = 200, loss = 0.021052991971373558,
# epoch = 14, i = 300, loss = 0.020768163725733757,
# epoch = 14, i = 400, loss = -0.007739401422441006,
# epoch = 14, i = 500, loss = -0.017615675926208496,
# epoch = 14, i = 600, loss = -0.011404339224100113,
# epoch = 14, i = 700, loss = -0.08220186084508896,
# epoch = 14, i = 800, loss = -0.01577838696539402,
# epoch = 14, i = 900, loss = -0.020042147487401962,
# epoch = 14, i = 1000, loss = -0.06481988728046417,
# epoch = 14, i = 1100, loss = -0.05508164316415787,
# epoch = 14, i = 1200, loss = -0.045686982572078705,
# epoch = 14, i = 1300, loss = -0.015255169942975044,
# evaluating model on dev and test...
# dev_acc: 0.5024500489234924, dev_rmse: 2.7731494903564453
# test_acc: 0.5241000056266785, test_rmse: 2.5215868949890137
# learning rate is 0.00043002917732064424
# epoch = 15, i = 0, loss = -0.009330349043011665,
# epoch = 15, i = 100, loss = 0.004605635069310665,
# epoch = 15, i = 200, loss = -0.056561846286058426,
# epoch = 15, i = 300, loss = -0.0633637085556984,
# epoch = 15, i = 400, loss = 0.016701165586709976,
# epoch = 15, i = 500, loss = -0.056471019983291626,
# epoch = 15, i = 600, loss = -0.001917896792292595,
# epoch = 15, i = 700, loss = -0.03564312309026718,
# epoch = 15, i = 800, loss = -0.0326668843626976,
# epoch = 15, i = 900, loss = -0.07592286914587021,
# epoch = 15, i = 1000, loss = 0.016699574887752533,
# epoch = 15, i = 1100, loss = -0.03735816478729248,
# epoch = 15, i = 1200, loss = -0.0591730922460556,
# epoch = 15, i = 1300, loss = -0.031197886914014816,
# evaluating model on dev and test...
# dev_acc: 0.5112001895904541, dev_rmse: 2.728731393814087
# test_acc: 0.5276399850845337, test_rmse: 2.4773776531219482
# learning rate is 0.0004257288855474378
# epoch = 16, i = 0, loss = -0.02222275733947754,
# epoch = 16, i = 100, loss = -0.030443135648965836,
# epoch = 16, i = 200, loss = -0.02933957800269127,
# epoch = 16, i = 300, loss = -0.041051946580410004,
# epoch = 16, i = 400, loss = -0.05427076667547226,
# epoch = 16, i = 500, loss = -0.04277333989739418,
# epoch = 16, i = 600, loss = -0.05178598687052727,
# epoch = 16, i = 700, loss = -0.015442674979567528,
# epoch = 16, i = 800, loss = -0.05756351724267006,
# epoch = 16, i = 900, loss = -0.052085720002651215,
# epoch = 16, i = 1000, loss = -0.038313157856464386,
# epoch = 16, i = 1100, loss = 0.039275214076042175,
# epoch = 16, i = 1200, loss = -0.044039227068424225,
# epoch = 16, i = 1300, loss = -0.021138031035661697,
# evaluating model on dev and test...
# dev_acc: 0.5068759322166443, dev_rmse: 2.763779640197754
# test_acc: 0.5217800140380859, test_rmse: 2.521110773086548
# learning rate is 0.0004214715966919634
# epoch = 17, i = 0, loss = -0.04622954875230789,
# epoch = 17, i = 100, loss = -0.04853405803442001,
# epoch = 17, i = 200, loss = -0.02505662478506565,
# epoch = 17, i = 300, loss = -0.12221543490886688,
# epoch = 17, i = 400, loss = -0.003668280318379402,
# epoch = 17, i = 500, loss = -0.014453635551035404,
# epoch = 17, i = 600, loss = -0.012337535619735718,
# epoch = 17, i = 700, loss = -0.0827469751238823,
# epoch = 17, i = 800, loss = -0.036720480769872665,
# epoch = 17, i = 900, loss = -0.03215314447879791,
# epoch = 17, i = 1000, loss = -0.017369864508509636,
# epoch = 17, i = 1100, loss = -0.03179262578487396,
# epoch = 17, i = 1200, loss = -0.06541384011507034,
# epoch = 17, i = 1300, loss = -0.04456733167171478,
# evaluating model on dev and test...
# dev_acc: 0.5163204073905945, dev_rmse: 2.7100791931152344
# test_acc: 0.5290399789810181, test_rmse: 2.4594309329986572
# learning rate is 0.00041725688072504375
# epoch = 18, i = 0, loss = -0.05290728807449341,
# epoch = 18, i = 100, loss = -0.004681998863816261,
# epoch = 18, i = 200, loss = -0.06428239494562149,
# epoch = 18, i = 300, loss = 0.009481215849518776,
# epoch = 18, i = 400, loss = -0.040360063314437866,
# epoch = 18, i = 500, loss = -0.05982333421707153,
# epoch = 18, i = 600, loss = -0.02787957154214382,
# epoch = 18, i = 700, loss = 0.06792306154966354,
# epoch = 18, i = 800, loss = 0.00030883029103279114,
# epoch = 18, i = 900, loss = -0.034065745770931244,
# epoch = 18, i = 1000, loss = -0.04183529317378998,
# epoch = 18, i = 1100, loss = -0.03222022205591202,
# epoch = 18, i = 1200, loss = 0.009185872972011566,
# epoch = 18, i = 1300, loss = 0.006621114909648895,
# evaluating model on dev and test...
# dev_acc: 0.5143897533416748, dev_rmse: 2.7052109241485596
# test_acc: 0.5254600048065186, test_rmse: 2.477942705154419
# learning rate is 0.00041308431191779333
# epoch = 19, i = 0, loss = -0.04666287451982498,
# epoch = 19, i = 100, loss = -0.002405330538749695,
# epoch = 19, i = 200, loss = 0.00466554332524538,
# epoch = 19, i = 300, loss = -0.029950443655252457,
# epoch = 19, i = 400, loss = -0.01406443677842617,
# epoch = 19, i = 500, loss = -0.027637267485260963,
# epoch = 19, i = 600, loss = 0.00186951644718647,
# epoch = 19, i = 700, loss = -0.08153592050075531,
# epoch = 19, i = 800, loss = -0.005767049267888069,
# epoch = 19, i = 900, loss = -0.06049109250307083,
# epoch = 19, i = 1000, loss = -0.028495188802480698,
# epoch = 19, i = 1100, loss = 0.03113296441733837,
# epoch = 19, i = 1200, loss = -0.005044771358370781,
# epoch = 19, i = 1300, loss = -0.04393940791487694,
# evaluating model on dev and test...
# dev_acc: 0.514632523059845, dev_rmse: 2.725802421569824
# test_acc: 0.5289000272750854, test_rmse: 2.480403184890747
# learning rate is 0.00040895346879861536
# saving model..
# Done.
# epoch = 20, i = 0, loss = -0.02513762190937996,
# epoch = 20, i = 100, loss = -0.022436555474996567,
# epoch = 20, i = 200, loss = -0.02145293541252613,
# epoch = 20, i = 300, loss = -0.03451547026634216,
# epoch = 20, i = 400, loss = 0.016231108456850052,
# epoch = 20, i = 500, loss = -0.05440431088209152,
# epoch = 20, i = 600, loss = -0.007535208016633987,
# epoch = 20, i = 700, loss = -0.015393007546663284,
# epoch = 20, i = 800, loss = -0.07043559849262238,
# epoch = 20, i = 900, loss = -0.021768655627965927,
# epoch = 20, i = 1000, loss = -0.0680909976363182,
# epoch = 20, i = 1100, loss = -0.01893952302634716,
# epoch = 20, i = 1200, loss = -0.013626199215650558,
# epoch = 20, i = 1300, loss = -0.013823166489601135,
# evaluating model on dev and test...
# dev_acc: 0.511781632900238, dev_rmse: 2.723191738128662
# test_acc: 0.5333999991416931, test_rmse: 2.466738700866699
# learning rate is 0.0004048639341106292
# epoch = 21, i = 0, loss = 0.029502548277378082,
# epoch = 21, i = 100, loss = -0.020116683095693588,
# epoch = 21, i = 200, loss = -0.03251120448112488,
# epoch = 21, i = 300, loss = -0.040952615439891815,
# epoch = 21, i = 400, loss = -0.03967025876045227,
# epoch = 21, i = 500, loss = -0.01082039438188076,
# epoch = 21, i = 600, loss = -0.04195699840784073,
# epoch = 21, i = 700, loss = -0.054316580295562744,
# epoch = 21, i = 800, loss = -0.0012135226279497147,
# epoch = 21, i = 900, loss = -0.04432675614953041,
# epoch = 21, i = 1000, loss = -0.0380096510052681,
# epoch = 21, i = 1100, loss = -0.05931556969881058,
# epoch = 21, i = 1200, loss = -0.02932349219918251,
# epoch = 21, i = 1300, loss = -0.004182497039437294,
# evaluating model on dev and test...
# dev_acc: 0.5148131251335144, dev_rmse: 2.714585304260254
# test_acc: 0.532039999961853, test_rmse: 2.4655628204345703
# learning rate is 0.0004008152947695229
# epoch = 22, i = 0, loss = -0.020863570272922516,
# epoch = 22, i = 100, loss = -0.04575936123728752,
# epoch = 22, i = 200, loss = -0.04825165122747421,
# epoch = 22, i = 300, loss = 0.01997506245970726,
# epoch = 22, i = 400, loss = -0.037461910396814346,
# epoch = 22, i = 500, loss = -0.008546613156795502,
# epoch = 22, i = 600, loss = 0.010854838415980339,
# epoch = 22, i = 700, loss = -0.005924638360738754,
# epoch = 22, i = 800, loss = -0.02150937356054783,
# epoch = 22, i = 900, loss = 0.011675260961055756,
# epoch = 22, i = 1000, loss = 0.010845807380974293,
# epoch = 22, i = 1100, loss = 0.0005209315568208694,
# epoch = 22, i = 1200, loss = -0.007632093504071236,
# epoch = 22, i = 1300, loss = -0.01976298727095127,
# evaluating model on dev and test...
# dev_acc: 0.5168059468269348, dev_rmse: 2.714928388595581
# test_acc: 0.534820020198822, test_rmse: 2.4589834213256836
# learning rate is 0.0003968071418218277
# epoch = 23, i = 0, loss = -0.01793215423822403,
# epoch = 23, i = 100, loss = -0.01790550909936428,
# epoch = 23, i = 200, loss = -0.02947722002863884,
# epoch = 23, i = 300, loss = -0.00021973252296447754,
# epoch = 23, i = 400, loss = 0.001245744526386261,
# epoch = 23, i = 500, loss = 0.004539689980447292,
# epoch = 23, i = 600, loss = -0.038454510271549225,
# epoch = 23, i = 700, loss = -0.016481373459100723,
# epoch = 23, i = 800, loss = -0.052177950739860535,
# epoch = 23, i = 900, loss = -0.11259087175130844,
# epoch = 23, i = 1000, loss = 0.02983025833964348,
# epoch = 23, i = 1100, loss = -0.009224185720086098,
# epoch = 23, i = 1200, loss = -0.03512309491634369,
# epoch = 23, i = 1300, loss = -0.06071258336305618,
# evaluating model on dev and test...
# dev_acc: 0.5201422572135925, dev_rmse: 2.7013370990753174
# test_acc: 0.5337799787521362, test_rmse: 2.475156545639038
# learning rate is 0.0003928390704036094
# epoch = 24, i = 0, loss = -0.04265045374631882,
# epoch = 24, i = 100, loss = -0.07745496183633804,
# epoch = 24, i = 200, loss = 0.036247093230485916,
# epoch = 24, i = 300, loss = -0.013814199715852737,
# epoch = 24, i = 400, loss = -0.01735074259340763,
# epoch = 24, i = 500, loss = -0.07420775294303894,
# epoch = 24, i = 600, loss = 0.0076128579676151276,
# epoch = 24, i = 700, loss = -0.028663452714681625,
# epoch = 24, i = 800, loss = -0.04343057796359062,
# epoch = 24, i = 900, loss = -0.020952386781573296,
# epoch = 24, i = 1000, loss = -0.0059295762330293655,
# epoch = 24, i = 1100, loss = -0.0010383334010839462,
# epoch = 24, i = 1200, loss = -0.014862822368741035,
# epoch = 24, i = 1300, loss = -0.005306830629706383,
# evaluating model on dev and test...
# dev_acc: 0.5194027423858643, dev_rmse: 2.6939711570739746
# test_acc: 0.5341200232505798, test_rmse: 2.4333105087280273
# learning rate is 0.00038891067969957333
# epoch = 25, i = 0, loss = -0.05200524628162384,
# epoch = 25, i = 100, loss = -0.0009231604635715485,
# epoch = 25, i = 200, loss = 0.037050165235996246,
# epoch = 25, i = 300, loss = -0.04917237162590027,
# epoch = 25, i = 400, loss = -0.047512758523225784,
# epoch = 25, i = 500, loss = -0.01865786500275135,
# epoch = 25, i = 600, loss = -0.020872538909316063,
# epoch = 25, i = 700, loss = -0.04474486783146858,
# epoch = 25, i = 800, loss = -0.023422617465257645,
# epoch = 25, i = 900, loss = -0.040594421327114105,
# epoch = 25, i = 1000, loss = 0.007157407701015472,
# epoch = 25, i = 1100, loss = -0.051608070731163025,
# epoch = 25, i = 1200, loss = -0.024983977898955345,
# epoch = 25, i = 1300, loss = -0.00580415315926075,
# evaluating model on dev and test...
# dev_acc: 0.5193575620651245, dev_rmse: 2.7231709957122803
# test_acc: 0.5410400032997131, test_rmse: 2.4630467891693115
# learning rate is 0.0003850215729025776
# epoch = 26, i = 0, loss = -0.0707152858376503,
# epoch = 26, i = 100, loss = 0.005375239998102188,
# epoch = 26, i = 200, loss = -0.019447948783636093,
# epoch = 26, i = 300, loss = -0.04487685114145279,
# epoch = 26, i = 400, loss = -0.026472028344869614,
# epoch = 26, i = 500, loss = -0.017689455300569534,
# epoch = 26, i = 600, loss = -0.036080628633499146,
# epoch = 26, i = 700, loss = -0.02308501861989498,
# epoch = 26, i = 800, loss = -0.08261654525995255,
# epoch = 26, i = 900, loss = -0.038340307772159576,
# epoch = 26, i = 1000, loss = -0.024894310161471367,
# epoch = 26, i = 1100, loss = 0.0016640834510326385,
# epoch = 26, i = 1200, loss = 0.028415147215127945,
# epoch = 26, i = 1300, loss = -0.034131743013858795,
# evaluating model on dev and test...
# dev_acc: 0.5217398405075073, dev_rmse: 2.705357074737549
# test_acc: 0.5421800017356873, test_rmse: 2.4282093048095703
# learning rate is 0.0003811713571735518
# epoch = 27, i = 0, loss = -0.01997397467494011,
# epoch = 27, i = 100, loss = 0.03013373166322708,
# epoch = 27, i = 200, loss = -0.008085928857326508,
# epoch = 27, i = 300, loss = -0.03359316661953926,
# epoch = 27, i = 400, loss = -0.05254971235990524,
# epoch = 27, i = 500, loss = 0.00646536611020565,
# epoch = 27, i = 600, loss = -0.031601086258888245,
# epoch = 27, i = 700, loss = -0.008115541189908981,
# epoch = 27, i = 800, loss = -0.05587035417556763,
# epoch = 27, i = 900, loss = 0.0062269847840070724,
# epoch = 27, i = 1000, loss = 0.04141880199313164,
# epoch = 27, i = 1100, loss = -0.018373902887105942,
# epoch = 27, i = 1200, loss = -0.04682707041501999,
# epoch = 27, i = 1300, loss = -0.08595170080661774,
# evaluating model on dev and test...
# dev_acc: 0.522693932056427, dev_rmse: 2.705148458480835
# test_acc: 0.5418599843978882, test_rmse: 2.4744696617126465
# learning rate is 0.0003773596436018163
# epoch = 28, i = 0, loss = 0.009713897481560707,
# epoch = 28, i = 100, loss = -0.021301165223121643,
# epoch = 28, i = 200, loss = 0.017959140241146088,
# epoch = 28, i = 300, loss = -0.005610305815935135,
# epoch = 28, i = 400, loss = -0.07971067726612091,
# epoch = 28, i = 500, loss = -0.013644076883792877,
# epoch = 28, i = 600, loss = 0.0033105751499533653,
# epoch = 28, i = 700, loss = -0.013679862022399902,
# epoch = 28, i = 800, loss = -0.08829423040151596,
# epoch = 28, i = 900, loss = -0.019435370340943336,
# epoch = 28, i = 1000, loss = -0.019611265510320663,
# epoch = 28, i = 1100, loss = -0.009654340334236622,
# epoch = 28, i = 1200, loss = -0.018274080008268356,
# epoch = 28, i = 1300, loss = -0.07092958688735962,
# evaluating model on dev and test...
# dev_acc: 0.5223777890205383, dev_rmse: 2.6794941425323486
# test_acc: 0.5383399724960327, test_rmse: 2.4311726093292236
# learning rate is 0.0003735860471657981
# epoch = 29, i = 0, loss = -0.039708033204078674,
# epoch = 29, i = 100, loss = -0.02671155147254467,
# epoch = 29, i = 200, loss = -0.00587358046323061,
# epoch = 29, i = 300, loss = -0.01016290858387947,
# epoch = 29, i = 400, loss = -0.06120491027832031,
# epoch = 29, i = 500, loss = -0.020307010039687157,
# epoch = 29, i = 600, loss = -0.05556678771972656,
# epoch = 29, i = 700, loss = -0.0114141795784235,
# epoch = 29, i = 800, loss = -0.047061048448085785,
# epoch = 29, i = 900, loss = -0.011726913042366505,
# epoch = 29, i = 1000, loss = -0.02872343547642231,
# epoch = 29, i = 1100, loss = -0.03499883413314819,
# epoch = 29, i = 1200, loss = -0.008734868839383125,
# epoch = 29, i = 1300, loss = -0.03849528357386589,
# evaluating model on dev and test...
# dev_acc: 0.5268939733505249, dev_rmse: 2.682105302810669
# test_acc: 0.5459799766540527, test_rmse: 2.444054126739502
# learning rate is 0.0003698501866941401
# saving model..
# Done.
# epoch = 30, i = 0, loss = 0.00606207549571991,
# epoch = 30, i = 100, loss = -0.02601328305900097,
# epoch = 30, i = 200, loss = 0.0007190294563770294,
# epoch = 30, i = 300, loss = -0.04593495652079582,
# epoch = 30, i = 400, loss = -0.030741307884454727,
# epoch = 30, i = 500, loss = -0.003700941801071167,
# epoch = 30, i = 600, loss = 0.025413136929273605,
# epoch = 30, i = 700, loss = -0.027225537225604057,
# epoch = 30, i = 800, loss = -0.06677860766649246,
# epoch = 30, i = 900, loss = -0.04143529385328293,
# epoch = 30, i = 1000, loss = -0.05085274204611778,
# epoch = 30, i = 1100, loss = 0.000973312184214592,
# epoch = 30, i = 1200, loss = 0.013326304033398628,
# epoch = 30, i = 1300, loss = -0.08013378083705902,
# evaluating model on dev and test...
# dev_acc: 0.5265722274780273, dev_rmse: 2.6790199279785156
# test_acc: 0.5434200167655945, test_rmse: 2.430884599685669
# learning rate is 0.00036615168482719875
# epoch = 31, i = 0, loss = -0.02542085573077202,
# epoch = 31, i = 100, loss = -0.07572626322507858,
# epoch = 31, i = 200, loss = 0.14277280867099762,
# epoch = 31, i = 300, loss = -0.03881339356303215,
# epoch = 31, i = 400, loss = -0.04255299270153046,
# epoch = 31, i = 500, loss = -0.02309599705040455,
# epoch = 31, i = 600, loss = -0.03339274227619171,
# epoch = 31, i = 700, loss = -0.058806195855140686,
# epoch = 31, i = 800, loss = 0.009014436975121498,
# epoch = 31, i = 900, loss = -0.0023385584354400635,
# epoch = 31, i = 1000, loss = -0.07314614951610565,
# epoch = 31, i = 1100, loss = -0.015964830294251442,
# epoch = 31, i = 1200, loss = -0.01793001778423786,
# epoch = 31, i = 1300, loss = -0.02459050714969635,
# evaluating model on dev and test...
# dev_acc: 0.523834228515625, dev_rmse: 2.6953537464141846
# test_acc: 0.5425000190734863, test_rmse: 2.434337615966797
# learning rate is 0.0003624901679789267
# epoch = 32, i = 0, loss = 0.02010633610188961,
# epoch = 32, i = 100, loss = -0.003888070583343506,
# epoch = 32, i = 200, loss = -0.025561844930052757,
# epoch = 32, i = 300, loss = -0.035245031118392944,
# epoch = 32, i = 400, loss = -0.06476840376853943,
# epoch = 32, i = 500, loss = 0.004511116072535515,
# epoch = 32, i = 600, loss = 0.014127781614661217,
# epoch = 32, i = 700, loss = -0.034750573337078094,
# epoch = 32, i = 800, loss = -0.07545223832130432,
# epoch = 32, i = 900, loss = -0.01304186973720789,
# epoch = 32, i = 1000, loss = -0.06854849308729172,
# epoch = 32, i = 1100, loss = 0.03712476044893265,
# epoch = 32, i = 1200, loss = -0.006470521911978722,
# epoch = 32, i = 1300, loss = 0.01644851081073284,
# evaluating model on dev and test...
# dev_acc: 0.5235294103622437, dev_rmse: 2.706348180770874
# test_acc: 0.5404000282287598, test_rmse: 2.4450767040252686
# learning rate is 0.00035886526629913746
# epoch = 33, i = 0, loss = -0.025827309116721153,
# epoch = 33, i = 100, loss = -0.02364427037537098,
# epoch = 33, i = 200, loss = -0.02194059267640114,
# epoch = 33, i = 300, loss = 0.017850060015916824,
# epoch = 33, i = 400, loss = -0.07068590819835663,
# epoch = 33, i = 500, loss = -0.06225728988647461,
# epoch = 33, i = 600, loss = -0.044444140046834946,
# epoch = 33, i = 700, loss = -0.07627369463443756,
# epoch = 33, i = 800, loss = -0.11139975488185883,
# epoch = 33, i = 900, loss = -0.01385083980858326,
# epoch = 33, i = 1000, loss = 0.01161268725991249,
# epoch = 33, i = 1100, loss = -0.00393715500831604,
# epoch = 33, i = 1200, loss = -0.050588540732860565,
# epoch = 33, i = 1300, loss = 0.00756651209667325,
# evaluating model on dev and test...
# dev_acc: 0.523478627204895, dev_rmse: 2.678493022918701
# test_acc: 0.5385000109672546, test_rmse: 2.4331459999084473
# learning rate is 0.00035527661363614604
# epoch = 34, i = 0, loss = -0.02492741495370865,
# epoch = 34, i = 100, loss = -0.034110039472579956,
# epoch = 34, i = 200, loss = -0.18003195524215698,
# epoch = 34, i = 300, loss = -0.014349792152643204,
# epoch = 34, i = 400, loss = -0.026489170268177986,
# epoch = 34, i = 500, loss = -0.0222582146525383,
# epoch = 34, i = 600, loss = -0.02044386975467205,
# epoch = 34, i = 700, loss = -0.0024414006620645523,
# epoch = 34, i = 800, loss = -0.01832369528710842,
# epoch = 34, i = 900, loss = 0.0033369865268468857,
# epoch = 34, i = 1000, loss = -0.005761420354247093,
# epoch = 34, i = 1100, loss = 0.007852050475776196,
# epoch = 34, i = 1200, loss = -0.04354717954993248,
# epoch = 34, i = 1300, loss = -0.008851205930113792,
# evaluating model on dev and test...
# dev_acc: 0.5221971273422241, dev_rmse: 2.678809404373169
# test_acc: 0.5383800268173218, test_rmse: 2.4408605098724365
# learning rate is 0.00035172384749978456
# epoch = 35, i = 0, loss = -0.04525972530245781,
# epoch = 35, i = 100, loss = -0.016529539600014687,
# epoch = 35, i = 200, loss = -0.027578866109251976,
# epoch = 35, i = 300, loss = -0.03042466752231121,
# epoch = 35, i = 400, loss = -0.017262862995266914,
# epoch = 35, i = 500, loss = -0.022310644388198853,
# epoch = 35, i = 600, loss = -0.015062892809510231,
# epoch = 35, i = 700, loss = -0.026159627363085747,
# epoch = 35, i = 800, loss = -0.013587994500994682,
# epoch = 35, i = 900, loss = -0.04635429382324219,
# epoch = 35, i = 1000, loss = 0.002757119946181774,
# epoch = 35, i = 1100, loss = -0.012830853462219238,
# epoch = 35, i = 1200, loss = -0.05205807834863663,
# epoch = 35, i = 1300, loss = -0.019342707470059395,
# evaluating model on dev and test...
# dev_acc: 0.5254883170127869, dev_rmse: 2.703112840652466
# test_acc: 0.548520028591156, test_rmse: 2.428579807281494
# learning rate is 0.00034820660902478676
# epoch = 36, i = 0, loss = -0.01761370524764061,
# epoch = 36, i = 100, loss = -0.061877280473709106,
# epoch = 36, i = 200, loss = -0.03138669580221176,
# epoch = 36, i = 300, loss = -0.004561306908726692,
# epoch = 36, i = 400, loss = -0.04833636060357094,
# epoch = 36, i = 500, loss = 0.03695327043533325,
# epoch = 36, i = 600, loss = -0.046770647168159485,
# epoch = 36, i = 700, loss = -0.004506824538111687,
# epoch = 36, i = 800, loss = -0.014150785282254219,
# epoch = 36, i = 900, loss = -0.036159105598926544,
# epoch = 36, i = 1000, loss = -0.033635206520557404,
# epoch = 36, i = 1100, loss = -0.06258536875247955,
# epoch = 36, i = 1200, loss = -0.01729520782828331,
# epoch = 36, i = 1300, loss = -0.013344522565603256,
# evaluating model on dev and test...
# dev_acc: 0.5291577577590942, dev_rmse: 2.7035515308380127
# test_acc: 0.5488799810409546, test_rmse: 2.429485559463501
# learning rate is 0.0003447245429345389
# epoch = 37, i = 0, loss = -0.04100264608860016,
# epoch = 37, i = 100, loss = -0.03313612565398216,
# epoch = 37, i = 200, loss = -0.006439638324081898,
# epoch = 37, i = 300, loss = -0.044139184057712555,
# epoch = 37, i = 400, loss = -0.027420181781053543,
# epoch = 37, i = 500, loss = -0.03493750840425491,
# epoch = 37, i = 600, loss = 0.006597659084945917,
# epoch = 37, i = 700, loss = -0.004947527311742306,
# epoch = 37, i = 800, loss = 0.01571037247776985,
# epoch = 37, i = 900, loss = -0.02694648876786232,
# epoch = 37, i = 1000, loss = -0.04767255485057831,
# epoch = 37, i = 1100, loss = -0.00882795825600624,
# epoch = 37, i = 1200, loss = -0.010662954300642014,
# epoch = 37, i = 1300, loss = -0.056903935968875885,
# evaluating model on dev and test...
# dev_acc: 0.5249745845794678, dev_rmse: 2.691927194595337
# test_acc: 0.5429400205612183, test_rmse: 2.427879810333252
# learning rate is 0.00034127729750519346
# epoch = 38, i = 0, loss = -0.05017027258872986,
# epoch = 38, i = 100, loss = -0.040114130824804306,
# epoch = 38, i = 200, loss = -0.043324097990989685,
# epoch = 38, i = 300, loss = -0.028364475816488266,
# epoch = 38, i = 400, loss = -0.03563329204916954,
# epoch = 38, i = 500, loss = -0.016707031056284904,
# epoch = 38, i = 600, loss = -0.03547513112425804,
# epoch = 38, i = 700, loss = 0.03135782107710838,
# epoch = 38, i = 800, loss = -0.0029403381049633026,
# epoch = 38, i = 900, loss = -0.0066497791558504105,
# epoch = 38, i = 1000, loss = -0.04605785757303238,
# epoch = 38, i = 1100, loss = -0.009148776531219482,
# epoch = 38, i = 1200, loss = -0.03131938353180885,
# epoch = 38, i = 1300, loss = -0.027361568063497543,
# evaluating model on dev and test...
# dev_acc: 0.524161696434021, dev_rmse: 2.688181161880493
# test_acc: 0.546280026435852, test_rmse: 2.4468348026275635
# learning rate is 0.00033786452453014155
# epoch = 39, i = 0, loss = -0.05425422638654709,
# epoch = 39, i = 100, loss = -0.036865998059511185,
# epoch = 39, i = 200, loss = -0.02564152516424656,
# epoch = 39, i = 300, loss = -0.022511541843414307,
# epoch = 39, i = 400, loss = -0.05430852621793747,
# epoch = 39, i = 500, loss = -0.034877412021160126,
# epoch = 39, i = 600, loss = -0.01912464015185833,
# epoch = 39, i = 700, loss = -0.0170289296656847,
# epoch = 39, i = 800, loss = 0.01227920688688755,
# epoch = 39, i = 900, loss = -0.014230292290449142,
# epoch = 39, i = 1000, loss = -0.04636453837156296,
# epoch = 39, i = 1100, loss = -0.018397167325019836,
# epoch = 39, i = 1200, loss = -0.057178858667612076,
# epoch = 39, i = 1300, loss = -0.041525114327669144,
# evaluating model on dev and test...
# dev_acc: 0.5240882635116577, dev_rmse: 2.6888320446014404
# test_acc: 0.5451599955558777, test_rmse: 2.4288268089294434
# learning rate is 0.0003344858792848401
# saving model..
# Done.
# epoch = 40, i = 0, loss = -0.01999683305621147,
# epoch = 40, i = 100, loss = -0.0015671197324991226,
# epoch = 40, i = 200, loss = -0.03913162276148796,
# epoch = 40, i = 300, loss = -0.031720492988824844,
# epoch = 40, i = 400, loss = 0.021366305649280548,
# epoch = 40, i = 500, loss = -0.005761897191405296,
# epoch = 40, i = 600, loss = -0.01804606430232525,
# epoch = 40, i = 700, loss = -0.00919609796255827,
# epoch = 40, i = 800, loss = -0.058098211884498596,
# epoch = 40, i = 900, loss = -0.046445444226264954,
# epoch = 40, i = 1000, loss = -0.02375328540802002,
# epoch = 40, i = 1100, loss = -0.020383533090353012,
# epoch = 40, i = 1200, loss = -0.04537210613489151,
# epoch = 40, i = 1300, loss = -0.04138185828924179,
# evaluating model on dev and test...
# dev_acc: 0.529722273349762, dev_rmse: 2.6803789138793945
# test_acc: 0.5489199757575989, test_rmse: 2.4383602142333984
# learning rate is 0.00033114102049199175
# epoch = 41, i = 0, loss = -0.032617583870887756,
# epoch = 41, i = 100, loss = -0.009422361850738525,
# epoch = 41, i = 200, loss = -0.06301933526992798,
# epoch = 41, i = 300, loss = 0.009930411353707314,
# epoch = 41, i = 400, loss = -0.020866451784968376,
# epoch = 41, i = 500, loss = -0.02846609801054001,
# epoch = 41, i = 600, loss = -0.017252273857593536,
# epoch = 41, i = 700, loss = -0.01987401768565178,
# epoch = 41, i = 800, loss = -0.02766239456832409,
# epoch = 41, i = 900, loss = -0.22953231632709503,
# epoch = 41, i = 1000, loss = 0.010232111439108849,
# epoch = 41, i = 1100, loss = -0.055615633726119995,
# epoch = 41, i = 1200, loss = 0.008155140094459057,
# epoch = 41, i = 1300, loss = -0.013837096281349659,
# evaluating model on dev and test...
# dev_acc: 0.5280060768127441, dev_rmse: 2.6867737770080566
# test_acc: 0.5446799993515015, test_rmse: 2.445812702178955
# learning rate is 0.0003278296102870718
# epoch = 42, i = 0, loss = -0.04055551812052727,
# epoch = 42, i = 100, loss = -0.03808540850877762,
# epoch = 42, i = 200, loss = -0.0305235106498003,
# epoch = 42, i = 300, loss = -0.0213828943669796,
# epoch = 42, i = 400, loss = -0.025779809802770615,
# epoch = 42, i = 500, loss = -0.036287400871515274,
# epoch = 42, i = 600, loss = 0.010340831242501736,
# epoch = 42, i = 700, loss = -0.14359356462955475,
# epoch = 42, i = 800, loss = -0.014387475326657295,
# epoch = 42, i = 900, loss = -0.02259736880660057,
# epoch = 42, i = 1000, loss = -0.011671727523207664,
# epoch = 42, i = 1100, loss = -0.012177884578704834,
# epoch = 42, i = 1200, loss = 0.04878862202167511,
# epoch = 42, i = 1300, loss = -0.018793735653162003,
# evaluating model on dev and test...
# dev_acc: 0.5286609530448914, dev_rmse: 2.664461851119995
# test_acc: 0.5455800294876099, test_rmse: 2.4342966079711914
# learning rate is 0.0003245513141842011
# epoch = 43, i = 0, loss = -0.082644984126091,
# epoch = 43, i = 100, loss = -0.0034524425864219666,
# epoch = 43, i = 200, loss = -0.01692526787519455,
# epoch = 43, i = 300, loss = 0.01219167560338974,
# epoch = 43, i = 400, loss = -0.003092230297625065,
# epoch = 43, i = 500, loss = -0.08527463674545288,
# epoch = 43, i = 600, loss = 0.0031874338164925575,
# epoch = 43, i = 700, loss = -0.037125155329704285,
# epoch = 43, i = 800, loss = -0.020741522312164307,
# epoch = 43, i = 900, loss = -0.09773155301809311,
# epoch = 43, i = 1000, loss = -0.020786594599485397,
# epoch = 43, i = 1100, loss = 0.01790590025484562,
# epoch = 43, i = 1200, loss = -0.019155047833919525,
# epoch = 43, i = 1300, loss = -0.05589562654495239,
# evaluating model on dev and test...
# dev_acc: 0.5281246304512024, dev_rmse: 2.6731343269348145
# test_acc: 0.545199990272522, test_rmse: 2.4245412349700928
# learning rate is 0.00032130580104235905
# epoch = 44, i = 0, loss = -0.022837335243821144,
# epoch = 44, i = 100, loss = -0.016884636133909225,
# epoch = 44, i = 200, loss = -0.004620981402695179,
# epoch = 44, i = 300, loss = -0.07508747279644012,
# epoch = 44, i = 400, loss = -0.012456515803933144,
# epoch = 44, i = 500, loss = -0.011020321398973465,
# epoch = 44, i = 600, loss = -0.010373222641646862,
# epoch = 44, i = 700, loss = -0.027983393520116806,
# epoch = 44, i = 800, loss = -0.041302286088466644,
# epoch = 44, i = 900, loss = -0.09384976327419281,
# epoch = 44, i = 1000, loss = -0.019944343715906143,
# epoch = 44, i = 1100, loss = -0.031950630247592926,
# epoch = 44, i = 1200, loss = -0.0012488383799791336,
# epoch = 44, i = 1300, loss = -0.018109263852238655,
# evaluating model on dev and test...
# dev_acc: 0.5243762135505676, dev_rmse: 2.699968099594116
# test_acc: 0.5426200032234192, test_rmse: 2.442089319229126
# learning rate is 0.0003180927430319355
# epoch = 45, i = 0, loss = -0.02013438008725643,
# epoch = 45, i = 100, loss = -0.019191481173038483,
# epoch = 45, i = 200, loss = -0.016733314841985703,
# epoch = 45, i = 300, loss = -0.055552881211042404,
# epoch = 45, i = 400, loss = -0.0007611550390720367,
# epoch = 45, i = 500, loss = -0.024541279301047325,
# epoch = 45, i = 600, loss = -0.030246710404753685,
# epoch = 45, i = 700, loss = -0.050281550735235214,
# epoch = 45, i = 800, loss = -0.025566527619957924,
# epoch = 45, i = 900, loss = 0.0011743716895580292,
# epoch = 45, i = 1000, loss = -0.0486004464328289,
# epoch = 45, i = 1100, loss = 0.013019676320254803,
# epoch = 45, i = 1200, loss = -0.010953236371278763,
# epoch = 45, i = 1300, loss = -0.019266627728939056,
# evaluating model on dev and test...
# dev_acc: 0.5279327034950256, dev_rmse: 2.6872990131378174
# test_acc: 0.5420600175857544, test_rmse: 2.4211153984069824
# learning rate is 0.00031491181560161616
# epoch = 46, i = 0, loss = -0.025710690766572952,
# epoch = 46, i = 100, loss = -0.015931660309433937,
# epoch = 46, i = 200, loss = -0.021366320550441742,
# epoch = 46, i = 300, loss = -0.00349352415651083,
# epoch = 46, i = 400, loss = -0.02429555356502533,
# epoch = 46, i = 500, loss = -0.032621659338474274,
# epoch = 46, i = 600, loss = -0.021857228130102158,
# epoch = 46, i = 700, loss = -0.08524785190820694,
# epoch = 46, i = 800, loss = -0.013290014117956161,
# epoch = 46, i = 900, loss = -0.034107040613889694,
# epoch = 46, i = 1000, loss = 0.02143169194459915,
# epoch = 46, i = 1100, loss = -0.07772921025753021,
# epoch = 46, i = 1200, loss = -0.020162265747785568,
# epoch = 46, i = 1300, loss = -0.00687435083091259,
# evaluating model on dev and test...
# dev_acc: 0.5300666093826294, dev_rmse: 2.676964521408081
# test_acc: 0.5446400046348572, test_rmse: 2.4297735691070557
# learning rate is 0.00031176269744559996
# epoch = 47, i = 0, loss = -0.017144914716482162,
# epoch = 47, i = 100, loss = -0.0034023839980363846,
# epoch = 47, i = 200, loss = 0.011564867570996284,
# epoch = 47, i = 300, loss = -0.006338717415928841,
# epoch = 47, i = 400, loss = 0.006094733253121376,
# epoch = 47, i = 500, loss = -0.02093709260225296,
# epoch = 47, i = 600, loss = -0.01983252540230751,
# epoch = 47, i = 700, loss = -0.11849265545606613,
# epoch = 47, i = 800, loss = 0.027133824303746223,
# epoch = 47, i = 900, loss = -0.05045466870069504,
# epoch = 47, i = 1000, loss = 0.02493051066994667,
# epoch = 47, i = 1100, loss = 9.690225124359131e-05,
# epoch = 47, i = 1200, loss = -0.006903212517499924,
# epoch = 47, i = 1300, loss = -0.01634122058749199,
# evaluating model on dev and test...
# dev_acc: 0.5265665650367737, dev_rmse: 2.6787145137786865
# test_acc: 0.5455999970436096, test_rmse: 2.43799090385437
# learning rate is 0.00030864507047114397
# epoch = 48, i = 0, loss = -0.017758231610059738,
# epoch = 48, i = 100, loss = 0.025086620822548866,
# epoch = 48, i = 200, loss = -0.04076053202152252,
# epoch = 48, i = 300, loss = -0.061072640120983124,
# epoch = 48, i = 400, loss = -0.051290273666381836,
# epoch = 48, i = 500, loss = -0.022282220423221588,
# epoch = 48, i = 600, loss = -0.0317770391702652,
# epoch = 48, i = 700, loss = -0.04350429028272629,
# epoch = 48, i = 800, loss = 0.011424019932746887,
# epoch = 48, i = 900, loss = 0.009390264749526978,
# epoch = 48, i = 1000, loss = -0.04860730469226837,
# epoch = 48, i = 1100, loss = -0.03276141360402107,
# epoch = 48, i = 1200, loss = -0.02254781872034073,
# epoch = 48, i = 1300, loss = -0.06862134486436844,
# evaluating model on dev and test...
# dev_acc: 0.5293440222740173, dev_rmse: 2.670525074005127
# test_acc: 0.5523800253868103, test_rmse: 2.4182639122009277
# learning rate is 0.0003055586197664325
# epoch = 49, i = 0, loss = -0.022353501990437508,
# epoch = 49, i = 100, loss = 0.02665853500366211,
# epoch = 49, i = 200, loss = -0.01690845564007759,
# epoch = 49, i = 300, loss = -0.05993391200900078,
# epoch = 49, i = 400, loss = -0.04785861819982529,
# epoch = 49, i = 500, loss = -0.03258752450346947,
# epoch = 49, i = 600, loss = -0.06954485177993774,
# epoch = 49, i = 700, loss = -0.017526043578982353,
# epoch = 49, i = 800, loss = 0.010483765974640846,
# epoch = 49, i = 900, loss = -0.006027396768331528,
# epoch = 49, i = 1000, loss = -0.012472019530832767,
# epoch = 49, i = 1100, loss = -0.022098371759057045,
# epoch = 49, i = 1200, loss = -0.031089920550584793,
# epoch = 49, i = 1300, loss = -0.06584515422582626,
# evaluating model on dev and test...
# dev_acc: 0.5306424498558044, dev_rmse: 2.669351577758789
# test_acc: 0.5474399924278259, test_rmse: 2.4098548889160156
# learning rate is 0.0003025030335687682
# saving model..
# Done.
# epoch = 50, i = 0, loss = -0.07271663099527359,
# epoch = 50, i = 100, loss = -0.05698829144239426,
# epoch = 50, i = 200, loss = -0.050808608531951904,
# epoch = 50, i = 300, loss = 0.0019304705783724785,
# epoch = 50, i = 400, loss = -0.04592239111661911,
# epoch = 50, i = 500, loss = -0.01887112855911255,
# epoch = 50, i = 600, loss = -0.05769336223602295,
# epoch = 50, i = 700, loss = -0.0641331672668457,
# epoch = 50, i = 800, loss = -0.0295901857316494,
# epoch = 50, i = 900, loss = -0.032396018505096436,
# epoch = 50, i = 1000, loss = -0.0379745177924633,
# epoch = 50, i = 1100, loss = -0.019500555470585823,
# epoch = 50, i = 1200, loss = -0.014086494222283363,
# epoch = 50, i = 1300, loss = 0.0434422492980957,
# evaluating model on dev and test...
# dev_acc: 0.5286948084831238, dev_rmse: 2.6595418453216553
# test_acc: 0.5458999872207642, test_rmse: 2.431830644607544
# learning rate is 0.0002994780032330805
# epoch = 51, i = 0, loss = -0.028884993866086006,
# epoch = 51, i = 100, loss = -0.04473252594470978,
# epoch = 51, i = 200, loss = -0.0364287905395031,
# epoch = 51, i = 300, loss = -0.0473036989569664,
# epoch = 51, i = 400, loss = -0.04460885003209114,
# epoch = 51, i = 500, loss = -0.04708615690469742,
# epoch = 51, i = 600, loss = -0.022957541048526764,
# epoch = 51, i = 700, loss = -0.03354247286915779,
# epoch = 51, i = 800, loss = -0.014952735975384712,
# epoch = 51, i = 900, loss = -0.005396437831223011,
# epoch = 51, i = 1000, loss = -0.060849666595458984,
# epoch = 51, i = 1100, loss = -0.02058982104063034,
# epoch = 51, i = 1200, loss = -0.021055882796645164,
# epoch = 51, i = 1300, loss = -0.03335117548704147,
# evaluating model on dev and test...
# dev_acc: 0.5322908163070679, dev_rmse: 2.6773862838745117
# test_acc: 0.5527999997138977, test_rmse: 2.4135866165161133
# learning rate is 0.0002964832232007497
# epoch = 52, i = 0, loss = -0.006009687669575214,
# epoch = 52, i = 100, loss = -0.02093660831451416,
# epoch = 52, i = 200, loss = -0.037649691104888916,
# epoch = 52, i = 300, loss = -0.033837683498859406,
# epoch = 52, i = 400, loss = -0.0388849601149559,
# epoch = 52, i = 500, loss = 0.005933291278779507,
# epoch = 52, i = 600, loss = -0.007172726094722748,
# epoch = 52, i = 700, loss = -0.005110911093652248,
# epoch = 52, i = 800, loss = 0.008760733529925346,
# epoch = 52, i = 900, loss = -0.045200690627098083,
# ...
# epoch = 82, i = 400, loss = -0.014639953151345253,
# epoch = 82, i = 500, loss = -0.00796202290803194,
# epoch = 82, i = 600, loss = -0.023646743968129158,
# epoch = 82, i = 700, loss = -0.025705022737383842,
# epoch = 82, i = 800, loss = -0.005390476435422897,
# epoch = 82, i = 900, loss = -0.023340506479144096,
# epoch = 82, i = 1000, loss = -0.023358561098575592,
# epoch = 82, i = 1100, loss = 0.00021937862038612366,
# epoch = 82, i = 1200, loss = -0.07192349433898926,
# epoch = 82, i = 1300, loss = -0.13106100261211395,
# evaluating model on dev and test...
# dev_acc: 0.534272313117981, dev_rmse: 2.6693832874298096
# test_acc: 0.5488200187683105, test_rmse: 2.4290740489959717
# learning rate is 0.00021711566339590582
# epoch = 83, i = 0, loss = 0.0003622695803642273,
# epoch = 83, i = 100, loss = -0.04625536873936653,
# epoch = 83, i = 200, loss = -0.05889501795172691,
# epoch = 83, i = 300, loss = -0.2590397000312805,
# epoch = 83, i = 400, loss = -0.024432644248008728,
# epoch = 83, i = 500, loss = -0.06641334295272827,
# epoch = 83, i = 600, loss = 0.0018011797219514847,
# epoch = 83, i = 700, loss = -0.007396325469017029,
# epoch = 83, i = 800, loss = -0.009141410700976849,
# epoch = 83, i = 900, loss = -0.01895313523709774,
# epoch = 83, i = 1000, loss = -0.013172554783523083,
# epoch = 83, i = 1100, loss = 0.010877152904868126,
# epoch = 83, i = 1200, loss = -0.01990152895450592,
# epoch = 83, i = 1300, loss = -0.02721676602959633,
# evaluating model on dev and test...
# dev_acc: 0.5351924896240234, dev_rmse: 2.663285493850708
# test_acc: 0.5535799860954285, test_rmse: 2.403996706008911
# learning rate is 0.00021494450676194676
# epoch = 84, i = 0, loss = -0.04532240703701973,
# epoch = 84, i = 100, loss = -0.03726837784051895,
# epoch = 84, i = 200, loss = -0.006019663996994495,
# epoch = 84, i = 300, loss = 0.016207817941904068,
# epoch = 84, i = 400, loss = -0.03121761977672577,
# epoch = 84, i = 500, loss = -0.06824121624231339,
# epoch = 84, i = 600, loss = -0.23362264037132263,
# epoch = 84, i = 700, loss = -0.00854199007153511,
# epoch = 84, i = 800, loss = -0.029496517032384872,
# epoch = 84, i = 900, loss = 0.037883926182985306,
# epoch = 84, i = 1000, loss = -0.03160717710852623,
# epoch = 84, i = 1100, loss = -0.034329853951931,
# epoch = 84, i = 1200, loss = -0.0391862578690052,
# epoch = 84, i = 1300, loss = -0.02601105347275734,
# evaluating model on dev and test...
# dev_acc: 0.5345884561538696, dev_rmse: 2.674612283706665
# test_acc: 0.5521399974822998, test_rmse: 2.425654649734497
# learning rate is 0.0002127950616943273
# epoch = 85, i = 0, loss = -0.03454015031456947,
# epoch = 85, i = 100, loss = -0.1663215458393097,
# epoch = 85, i = 200, loss = -0.018571708351373672,
# epoch = 85, i = 300, loss = -0.06288906931877136,
# epoch = 85, i = 400, loss = -0.0010499227792024612,
# epoch = 85, i = 500, loss = -0.008623035624623299,
# epoch = 85, i = 600, loss = 0.015741972252726555,
# epoch = 85, i = 700, loss = -0.021627122536301613,
# epoch = 85, i = 800, loss = -0.029255647212266922,
# epoch = 85, i = 900, loss = -0.04499804228544235,
# epoch = 85, i = 1000, loss = -0.007525538094341755,
# epoch = 85, i = 1100, loss = 0.006941957399249077,
# epoch = 85, i = 1200, loss = -0.034516990184783936,
# epoch = 85, i = 1300, loss = 0.00950825959444046,
# evaluating model on dev and test...
# dev_acc: 0.5365078449249268, dev_rmse: 2.663963794708252
# test_acc: 0.5548400282859802, test_rmse: 2.396622657775879
# learning rate is 0.00021066711107738402
# epoch = 86, i = 0, loss = 0.0008034324273467064,
# epoch = 86, i = 100, loss = -0.0035034334287047386,
# epoch = 86, i = 200, loss = -0.020615611225366592,
# epoch = 86, i = 300, loss = -0.02653803862631321,
# epoch = 86, i = 400, loss = -0.06726724654436111,
# epoch = 86, i = 500, loss = -0.056737709790468216,
# epoch = 86, i = 600, loss = -0.04283127188682556,
# epoch = 86, i = 700, loss = 0.004666194319725037,
# epoch = 86, i = 800, loss = -0.044607244431972504,
# epoch = 86, i = 900, loss = -0.017837155610322952,
# epoch = 86, i = 1000, loss = -0.042575668543577194,
# epoch = 86, i = 1100, loss = -0.004379473626613617,
# epoch = 86, i = 1200, loss = -0.026339076459407806,
# epoch = 86, i = 1300, loss = -0.00231938436627388,
# evaluating model on dev and test...
# dev_acc: 0.5350965261459351, dev_rmse: 2.685365676879883
# test_acc: 0.5552999973297119, test_rmse: 2.4127578735351562
# learning rate is 0.00020856043996661018
# epoch = 87, i = 0, loss = -0.04271011799573898,
# epoch = 87, i = 100, loss = -0.053480364382267,
# epoch = 87, i = 200, loss = -0.08209425210952759,
# epoch = 87, i = 300, loss = -0.016140080988407135,
# epoch = 87, i = 400, loss = 0.006007544230669737,
# epoch = 87, i = 500, loss = -0.02268250286579132,
# epoch = 87, i = 600, loss = -0.016618600115180016,
# epoch = 87, i = 700, loss = -0.0015030419453978539,
# epoch = 87, i = 800, loss = -0.17508825659751892,
# epoch = 87, i = 900, loss = -0.0402020663022995,
# epoch = 87, i = 1000, loss = -0.0006725331768393517,
# epoch = 87, i = 1100, loss = -0.01897810958325863,
# epoch = 87, i = 1200, loss = -0.04977833479642868,
# epoch = 87, i = 1300, loss = -0.024807706475257874,
# evaluating model on dev and test...
# dev_acc: 0.5360223650932312, dev_rmse: 2.6650760173797607
# test_acc: 0.5523999929428101, test_rmse: 2.410062313079834
# learning rate is 0.0002064748355669441
# epoch = 88, i = 0, loss = -0.016849596053361893,
# epoch = 88, i = 100, loss = 0.014035923406481743,
# epoch = 88, i = 200, loss = -0.024465294554829597,
# epoch = 88, i = 300, loss = -0.2022029012441635,
# epoch = 88, i = 400, loss = 0.03064725175499916,
# epoch = 88, i = 500, loss = -0.02416088432073593,
# epoch = 88, i = 600, loss = -0.0027461983263492584,
# epoch = 88, i = 700, loss = -0.03653379902243614,
# epoch = 88, i = 800, loss = 0.004353761672973633,
# epoch = 88, i = 900, loss = -0.02481185272336006,
# epoch = 88, i = 1000, loss = -0.03959839791059494,
# epoch = 88, i = 1100, loss = -0.006062794476747513,
# epoch = 88, i = 1200, loss = -0.028085866943001747,
# epoch = 88, i = 1300, loss = -0.04937978833913803,
# evaluating model on dev and test...
# dev_acc: 0.5351924896240234, dev_rmse: 2.663815498352051
# test_acc: 0.5501199960708618, test_rmse: 2.4097719192504883
# learning rate is 0.00020441008721127464
# epoch = 89, i = 0, loss = -0.01566856913268566,
# epoch = 89, i = 100, loss = 0.10547491163015366,
# epoch = 89, i = 200, loss = -0.04992316663265228,
# epoch = 89, i = 300, loss = 0.004533901810646057,
# epoch = 89, i = 400, loss = -0.011158209294080734,
# epoch = 89, i = 500, loss = -0.0037064403295516968,
# epoch = 89, i = 600, loss = -0.04301103204488754,
# epoch = 89, i = 700, loss = 0.009498227387666702,
# epoch = 89, i = 800, loss = -0.02910277433693409,
# epoch = 89, i = 900, loss = -0.013212861493229866,
# epoch = 89, i = 1000, loss = 0.00893656350672245,
# epoch = 89, i = 1100, loss = -0.03395761176943779,
# epoch = 89, i = 1200, loss = 0.031556691974401474,
# epoch = 89, i = 1300, loss = -0.002176196314394474,
# evaluating model on dev and test...
# dev_acc: 0.5361014008522034, dev_rmse: 2.6762263774871826
# test_acc: 0.5551000237464905, test_rmse: 2.4140422344207764
# learning rate is 0.0002023659863391619
# saving model..
# Done.
# epoch = 90, i = 0, loss = -0.03751063346862793,
# epoch = 90, i = 100, loss = -0.03253771364688873,
# epoch = 90, i = 200, loss = -0.01896147057414055,
# epoch = 90, i = 300, loss = -0.05329085886478424,
# epoch = 90, i = 400, loss = -0.043559230864048004,
# epoch = 90, i = 500, loss = -0.043932199478149414,
# epoch = 90, i = 600, loss = -0.0021336907520890236,
# epoch = 90, i = 700, loss = -0.053474754095077515,
# epoch = 90, i = 800, loss = -0.04778550565242767,
# epoch = 90, i = 900, loss = -0.033127233386039734,
# epoch = 90, i = 1000, loss = -0.03977923095226288,
# epoch = 90, i = 1100, loss = -0.07908900827169418,
# epoch = 90, i = 1200, loss = -0.021711720153689384,
# epoch = 90, i = 1300, loss = -0.0037382440641522408,
# evaluating model on dev and test...
# dev_acc: 0.5347013473510742, dev_rmse: 2.6718246936798096
# test_acc: 0.5519599914550781, test_rmse: 2.4284563064575195
# learning rate is 0.00020034232647577027
# epoch = 91, i = 0, loss = -0.1961130052804947,
# epoch = 91, i = 100, loss = -0.057609591633081436,
# epoch = 91, i = 200, loss = -0.035050198435783386,
# epoch = 91, i = 300, loss = -0.017354879528284073,
# epoch = 91, i = 400, loss = 0.005305485799908638,
# epoch = 91, i = 500, loss = 0.0027852822095155716,
# epoch = 91, i = 600, loss = -0.017051927745342255,
# epoch = 91, i = 700, loss = -0.02621205896139145,
# epoch = 91, i = 800, loss = -0.00974722858518362,
# epoch = 91, i = 900, loss = -0.01396472193300724,
# epoch = 91, i = 1000, loss = -0.02055794931948185,
# epoch = 91, i = 1100, loss = -0.13720251619815826,
# epoch = 91, i = 1200, loss = 0.005937190726399422,
# epoch = 91, i = 1300, loss = 0.008594583719968796,
# evaluating model on dev and test...
# dev_acc: 0.5360731482505798, dev_rmse: 2.664874792098999
# test_acc: 0.5521600246429443, test_rmse: 2.4010415077209473
# learning rate is 0.00019833890321101254
# epoch = 92, i = 0, loss = -0.01717349886894226,
# epoch = 92, i = 100, loss = -0.013177014887332916,
# epoch = 92, i = 200, loss = -0.018595857545733452,
# epoch = 92, i = 300, loss = -0.05108370631933212,
# epoch = 92, i = 400, loss = -0.027635453268885612,
# epoch = 92, i = 500, loss = 0.0016302159056067467,
# epoch = 92, i = 600, loss = 0.016829008236527443,
# epoch = 92, i = 700, loss = -0.021041076630353928,
# epoch = 92, i = 800, loss = -0.025019504129886627,
# epoch = 92, i = 900, loss = -0.023380717262625694,
# epoch = 92, i = 1000, loss = -0.05005878210067749,
# epoch = 92, i = 1100, loss = -0.045182906091213226,
# epoch = 92, i = 1200, loss = -0.02820177748799324,
# epoch = 92, i = 1300, loss = 0.01268819347023964,
# evaluating model on dev and test...
# dev_acc: 0.5358247756958008, dev_rmse: 2.6666431427001953
# test_acc: 0.5528200268745422, test_rmse: 2.4040799140930176
# learning rate is 0.00019635551417890244
# epoch = 93, i = 0, loss = -0.0317377895116806,
# epoch = 93, i = 100, loss = -0.030427470803260803,
# epoch = 93, i = 200, loss = -0.0516694150865078,
# epoch = 93, i = 300, loss = -0.038800328969955444,
# epoch = 93, i = 400, loss = 0.016455229371786118,
# epoch = 93, i = 500, loss = -0.030120767652988434,
# epoch = 93, i = 600, loss = -0.005617466755211353,
# epoch = 93, i = 700, loss = -0.022418107837438583,
# epoch = 93, i = 800, loss = -0.02889055386185646,
# epoch = 93, i = 900, loss = -0.02484165132045746,
# epoch = 93, i = 1000, loss = 0.005123239941895008,
# epoch = 93, i = 1100, loss = -0.019856292754411697,
# epoch = 93, i = 1200, loss = -0.0059031154960393906,
# epoch = 93, i = 1300, loss = -0.05707208439707756,
# evaluating model on dev and test...
# dev_acc: 0.5364401340484619, dev_rmse: 2.6713175773620605
# test_acc: 0.5548999905586243, test_rmse: 2.430884599685669
# learning rate is 0.0001943919590371134
# epoch = 94, i = 0, loss = -0.009814510121941566,
# epoch = 94, i = 100, loss = -0.02687833458185196,
# epoch = 94, i = 200, loss = -0.050436832010746,
# epoch = 94, i = 300, loss = 0.02104533277451992,
# epoch = 94, i = 400, loss = -0.27732229232788086,
# epoch = 94, i = 500, loss = -0.041779667139053345,
# epoch = 94, i = 600, loss = -0.036869801580905914,
# epoch = 94, i = 700, loss = -0.1038321852684021,
# epoch = 94, i = 800, loss = -0.018032457679510117,
# epoch = 94, i = 900, loss = -0.06281855702400208,
# epoch = 94, i = 1000, loss = -0.22616784274578094,
# epoch = 94, i = 1100, loss = 0.007614406291395426,
# epoch = 94, i = 1200, loss = -0.026677578687667847,
# epoch = 94, i = 1300, loss = -0.031683165580034256,
# evaluating model on dev and test...
# dev_acc: 0.5363610982894897, dev_rmse: 2.6734933853149414
# test_acc: 0.5519599914550781, test_rmse: 2.3968729972839355
# learning rate is 0.00019244803944674227
# epoch = 95, i = 0, loss = -0.004533451981842518,
# epoch = 95, i = 100, loss = -0.06525363028049469,
# epoch = 95, i = 200, loss = -0.20590300858020782,
# epoch = 95, i = 300, loss = -0.032123222947120667,
# epoch = 95, i = 400, loss = -0.001795879565179348,
# epoch = 95, i = 500, loss = -0.022970974445343018,
# epoch = 95, i = 600, loss = -0.03896249830722809,
# epoch = 95, i = 700, loss = -0.06841571629047394,
# epoch = 95, i = 800, loss = 0.024561967700719833,
# epoch = 95, i = 900, loss = -0.03613094985485077,
# epoch = 95, i = 1000, loss = -0.015048515051603317,
# epoch = 95, i = 1100, loss = 0.0002304697409272194,
# epoch = 95, i = 1200, loss = 0.025793980807065964,
# epoch = 95, i = 1300, loss = -0.015397045761346817,
# evaluating model on dev and test...
# dev_acc: 0.5351642966270447, dev_rmse: 2.667532205581665
# test_acc: 0.5546600222587585, test_rmse: 2.4150776863098145
# learning rate is 0.00019052355905227483
# epoch = 96, i = 0, loss = 0.011144151911139488,
# epoch = 96, i = 100, loss = -0.013409333303570747,
# epoch = 96, i = 200, loss = -0.007492745295166969,
# epoch = 96, i = 300, loss = -0.007658567279577255,
# epoch = 96, i = 400, loss = -0.011628770269453526,
# epoch = 96, i = 500, loss = -0.040063053369522095,
# epoch = 96, i = 600, loss = -0.05115713179111481,
# epoch = 96, i = 700, loss = 0.012897644191980362,
# epoch = 96, i = 800, loss = 0.0038888733834028244,
# epoch = 96, i = 900, loss = -0.04618535190820694,
# epoch = 96, i = 1000, loss = -0.003133874386548996,
# epoch = 96, i = 1100, loss = 0.0016721338033676147,
# epoch = 96, i = 1200, loss = -0.023578668013215065,
# epoch = 96, i = 1300, loss = -0.00507761538028717,
# evaluating model on dev and test...
# dev_acc: 0.5377667546272278, dev_rmse: 2.6673734188079834
# test_acc: 0.5567600131034851, test_rmse: 2.4197933673858643
# learning rate is 0.00018861832346175208
# epoch = 97, i = 0, loss = -0.0008097216486930847,
# epoch = 97, i = 100, loss = -0.05752285569906235,
# epoch = 97, i = 200, loss = 0.2826118767261505,
# epoch = 97, i = 300, loss = -0.046320490539073944,
# epoch = 97, i = 400, loss = -0.03780074045062065,
# epoch = 97, i = 500, loss = -0.05999017506837845,
# epoch = 97, i = 600, loss = -0.021010752767324448,
# epoch = 97, i = 700, loss = 0.011894836090505123,
# epoch = 97, i = 800, loss = 0.009169962257146835,
# epoch = 97, i = 900, loss = -0.027684569358825684,
# epoch = 97, i = 1000, loss = -0.02890719287097454,
# epoch = 97, i = 1100, loss = -0.04620916396379471,
# epoch = 97, i = 1200, loss = -0.0370369479060173,
# epoch = 97, i = 1300, loss = -0.026056859642267227,
# evaluating model on dev and test...
# dev_acc: 0.5368973612785339, dev_rmse: 2.6603057384490967
# test_acc: 0.5511800050735474, test_rmse: 2.391066551208496
# learning rate is 0.0001867321402271346
# epoch = 98, i = 0, loss = -0.0669800341129303,
# epoch = 98, i = 100, loss = -0.017804348841309547,
# epoch = 98, i = 200, loss = -0.03872142359614372,
# epoch = 98, i = 300, loss = -0.04223378002643585,
# epoch = 98, i = 400, loss = 0.0011569038033485413,
# epoch = 98, i = 500, loss = 0.006603127345442772,
# epoch = 98, i = 600, loss = -0.013240732252597809,
# epoch = 98, i = 700, loss = -0.059084419161081314,
# epoch = 98, i = 800, loss = -0.05173775553703308,
# epoch = 98, i = 900, loss = -0.04494685307145119,
# epoch = 98, i = 1000, loss = -0.03940354287624359,
# epoch = 98, i = 1100, loss = -0.03639163821935654,
# epoch = 98, i = 1200, loss = -0.018731500953435898,
# epoch = 98, i = 1300, loss = -0.03494465723633766,
# evaluating model on dev and test...
# dev_acc: 0.537682056427002, dev_rmse: 2.6759626865386963
# test_acc: 0.5542399883270264, test_rmse: 2.4232211112976074
# learning rate is 0.00018486481882486322
# epoch = 99, i = 0, loss = -0.002488408237695694,
# epoch = 99, i = 100, loss = -0.04258442297577858,
# epoch = 99, i = 200, loss = -0.013097025454044342,
# epoch = 99, i = 300, loss = -0.2995815873146057,
# epoch = 99, i = 400, loss = -0.0517985001206398,
# epoch = 99, i = 500, loss = -0.014621257781982422,
# epoch = 99, i = 600, loss = 0.003842223435640335,
# epoch = 99, i = 700, loss = -0.012275813147425652,
# epoch = 99, i = 800, loss = -0.031314849853515625,
# epoch = 99, i = 900, loss = -0.02487562596797943,
# epoch = 99, i = 1000, loss = -0.009308447130024433,
# epoch = 99, i = 1100, loss = -0.01211196556687355,
# epoch = 99, i = 1200, loss = -0.01377066969871521,
# epoch = 99, i = 1300, loss = -0.02526899054646492,
# evaluating model on dev and test...
# dev_acc: 0.538032054901123, dev_rmse: 2.6826839447021484
# test_acc: 0.5574600100517273, test_rmse: 2.4130892753601074

# %%
torch.save(model.state_dict(), "./saved_models/{}-epoch-99-acc".format(exp_name))

# %%
len(test_accs), len(dev_accs)
# Out:
# (100, 100)

# %%
top_dev_accs = sorted(zip(dev_accs, test_accs, test_rmses), reverse=True)
best_dev_acc, corr_test_acc, corr_test_rmse = top_dev_accs[0]
print("The best dev accuracy is {}. The corresponding test accuracy and test RMSE are {} and {} respectively".format(
    best_dev_acc, corr_test_acc, corr_test_rmse
))
