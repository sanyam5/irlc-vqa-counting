# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
# os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# %%
import torch
from torch.autograd import Variable

from dataset import Dictionary, HMQAFeatureDataset
from model import SoftCount
from config import *
from datetime import datetime, timedelta

import h5py
import numpy as np
import _pickle as pkl
import json
import torch.nn.functional as F

# %%
dictionary = Dictionary.load_from_file('data/dictionary.pkl')
# Out:
# loading dictionary from data/dictionary.pkl

# %%
# %%time
print('loading features from train hdf5 file')
train_h5_loc = './data/train36.hdf5'
with h5py.File(train_h5_loc, 'r') as hf:
    train_image_features = np.array(hf.get('image_features'))
    train_spatials_features = np.array(hf.get('spatial_features'))

# # can save time by writing the numpy array to disk
# np.save( open("/tmp/vqa/train_image_features", "wb"), train_image_features)
# np.save( open("/tmp/vqa/train_spatials_features", "wb"), train_spatials_features)

# %%
# %%time
# train_image_features = np.load(open("/tmp/vqa/train_image_features", "rb"))
# train_spatials_features = np.load(open("/tmp/vqa/train_spatials_features", "rb"))
# Out:
# CPU times: user 72 ms, sys: 15.9 s, total: 16 s
# Wall time: 1min 26s

# %%
from dataset import HMQAFeatureDataset

hmqa_train_dset = HMQAFeatureDataset(
    img_id2hqma_idx = pkl.load(open("./data/train36_imgid2idx.pkl", "rb")),
    image_features = train_image_features, 
    spatial_features = train_spatials_features, 
    qid2count = json.load(open("./data/how_many_qa/qid2count.json", "rb")), 
    qid2count2score = json.load(open("./data/how_many_qa/qid2count2score.json", "rb")), 
    name="train", 
    dictionary=dictionary
)
del HMQAFeatureDataset

# %%
len(hmqa_train_dset)
# Out:
# 83642

# %%
len(set([x["image_id"] for x in hmqa_train_dset.entries]))
# Out:
# 45546

# %%
# %%time
print('loading features from val hdf5 file')
val_h5_loc = './data/val36.hdf5'
with h5py.File(val_h5_loc, 'r') as hf:
    val_image_features = np.array(hf.get('image_features'))
    val_spatials_features = np.array(hf.get('spatial_features'))
    
# # can save time by writing the numpy array to disk
# np.save( open("/tmp/vqa/val_image_features", "wb"), val_image_features)
# np.save( open("/tmp/vqa/val_spatials_features", "wb"), val_spatials_features)

# %%
# %%time
# val_image_features = np.load(open("/tmp/vqa/val_image_features", "rb"))
# val_spatials_features = np.load(open("/tmp/vqa/val_spatials_features", "rb"))
# Out:
# CPU times: user 104 ms, sys: 20.3 s, total: 20.4 s
# Wall time: 58.9 s

# %%
# len(train_image_features)

from dataset import HMQAFeatureDataset

hmqa_dev_dset = HMQAFeatureDataset(
    img_id2hqma_idx = pkl.load(open("./data/val36_imgid2idx.pkl", "rb")),
    image_features = val_image_features, 
    spatial_features = val_spatials_features, 
    qid2count = json.load(open("./data/how_many_qa/qid2count.json", "rb")), 
    qid2count2score = json.load(open("./data/how_many_qa/qid2count2score.json", "rb")), 
    name="dev", 
    dictionary=dictionary
)

hmqa_test_dset = HMQAFeatureDataset(
    img_id2hqma_idx = pkl.load(open("./data/val36_imgid2idx.pkl", "rb")),
    image_features = val_image_features, 
    spatial_features = val_spatials_features, 
    qid2count = json.load(open("./data/how_many_qa/qid2count.json", "rb")), 
    qid2count2score = json.load(open("./data/how_many_qa/qid2count2score.json", "rb")), 
    name="test", 
    dictionary=dictionary
)
del HMQAFeatureDataset

# %%
len(hmqa_dev_dset), len(hmqa_test_dset)
# Out:
# (17714, 5000)

# %%
from torch.utils.data import DataLoader

hmqa_train_loader = DataLoader(hmqa_train_dset, 64, shuffle=True, num_workers=0)
hmqa_dev_loader = DataLoader(hmqa_dev_dset, 64, shuffle=True, num_workers=0)
hmqa_test_loader = DataLoader(hmqa_test_dset, 64, shuffle=True, num_workers=0)

# %%
def evaluate(model, hmqa_loader):
    
    all_acc = []
    all_se = []
    for i, (v_emb, b, q, c, c2s) in enumerate(hmqa_loader):
        v_emb = Variable(v_emb)
        b = Variable(b)
        q = Variable(q)
        c = Variable(c).view(-1).float()
        
        if USE_CUDA:
            v_emb = v_emb.cuda()
            b = b.cuda()
            q = q.cuda()
            c = c.cuda()
        
        kappa_0, rho = model.compute_vars(v_emb, b, q)
        count, greedy_count, logPA, entP, A, rho, P = model.take_mc_samples(kappa_0, rho, 1)
    
        nearest_pred = (greedy_count + 0.5).long().clamp(0, 20)
        for one_c, one_c2s, one_pred in zip(c, c2s, nearest_pred):
            one_c = one_c.cpu().data
            one_pred = one_pred.cpu().data
            
            all_se.append((one_c - one_pred.float()) ** 2)
            all_acc.append(one_c2s[one_pred])
    
    acc = torch.stack(all_acc).mean()
    rmse = torch.stack(all_se).mean() ** 0.5
    
    return acc, rmse

# %%
test_acc, test_rmse = evaluate(model, hmqa_test_loader)
test_acc, test_rmse
# Out:
# (tensor(0.5123), tensor(2.4301))

# %%
def isnan(x):
    check = (x != x)
    check = check.float().sum().data[0]
    return check > 0

# %%
from model import IRLC
model = IRLC()
del IRLC
# Out:
# initialising with glove embeddings
# done.

# %%
if USE_CUDA:
    model.cuda()
model
# Out:
# IRLC(
#   (ques_parser): QuestionParser(
#     (embd): Embedding(20159, 300, padding_idx=20158)
#     (rnn): GRU(300, 1024)
#     (dropout): Dropout(p=0.3)
#   )
#   (f_s): ScoringFunction(
#     (v_drop): Dropout(p=0.3)
#     (q_drop): Dropout(p=0.3)
#     (v_proj): FCNet(
#       (main): Sequential(
#         (0): Linear(in_features=2048, out_features=1024, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#       )
#     )
#     (q_proj): FCNet(
#       (main): Sequential(
#         (0): Linear(in_features=1024, out_features=1024, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#       )
#     )
#     (dropout): Dropout(p=0.3)
#   )
#   (W): Linear(in_features=1024, out_features=1, bias=True)
#   (f_rho): RhoScorer(
#     (W): Linear(in_features=1024, out_features=1, bias=True)
#     (f_rho): FCNet(
#       (main): Sequential(
#         (0): Linear(in_features=17, out_features=100, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#       )
#     )
#     (dense): Linear(in_features=100, out_features=1, bias=True)
#   )
#   (extra_params): ParameterList(
#       (0): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#   )
# )

# %%
test_acc, test_rmse = evaluate(model, hmqa_test_loader)
test_acc, test_rmse
# Out:
# (tensor(1.00000e-02 *
#         1.3900), tensor(17.3969))

# %%
opt = torch.optim.Adam(model.parameters(), lr=5e-4)
sched = torch.optim.lr_scheduler.ExponentialLR(opt, gamma=.99)

# %%
test_accs = []
test_rmses = []

dev_accs = []
dev_rmses = []

# %%
exp_name = "hope"

# %%
for epoch in range(0, 100):
    # adjust learning rate
    sched.step()
    print("learning rate is {}".format(opt.param_groups[0]["lr"]))
    
    # save model every 10 epochs
    if epoch % 10 == 0:
        print("saving model..")
        torch.save(model.state_dict(), "./saved_models/{}-epoch-{}-acc-{}".format(exp_name, epoch, test_acc))
        print("Done.")
    
    for i, (v_emb, b, q, c, _) in enumerate(hmqa_train_loader):
        v_emb = Variable(v_emb)
        b = Variable(b)
        q = Variable(q)
        c = Variable(c).view(-1).float()

        if USE_CUDA:
            v_emb = v_emb.cuda()
            q = q.cuda()
            c = c.cuda()
            b = b.cuda()

        B, k, _ = v_emb.size()

        kappa_0, rho = model.compute_vars(v_emb, b, q)
        if isnan(kappa_0) or isnan(rho) or isnan(model.eps):
            raise Exception("there are nans here")

        num_samples = 32
        count, greedy_count, logPA, entP, A, rho = model.take_mc_samples(kappa_0, rho, num_samples)
        c_gt = torch.cat([c] * num_samples)

        loss = model.get_loss(c_gt, count, greedy_count, logPA, entP, A, rho)

        if i % 100 == 0:
            print("epoch = {}, i = {}, loss = {},".format(epoch, i, loss.data[0],))

        opt.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm(model.parameters(), 0.25)
        opt.step()


    print("evaluating model on dev and test...")

    model.eval()
    dev_acc, dev_rmse = evaluate(model, hmqa_dev_loader)
    print("dev_acc: {}, dev_rmse: {}".format(dev_acc, dev_rmse))
    test_acc, test_rmse = evaluate(model, hmqa_test_loader)
    print("test_acc: {}, test_rmse: {}".format(test_acc, test_rmse))
    model.train()
    
    test_accs.append(test_acc)
    test_rmses.append(test_rmse)
    dev_accs.append(dev_acc)
    dev_rmses.append(dev_rmse)
# Out:
# learning rate is 0.0005
# saving model..
# Done.
# epoch = 0, i = 0, loss = 25.920881271362305,
# /home/sanyam/miniconda3/envs/py3t4/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/sanyam/miniconda3/envs/py3t4/lib/python3.6/site-packages/ipykernel_launcher.py:37: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# /home/sanyam/miniconda3/envs/py3t4/lib/python3.6/site-packages/ipykernel_launcher.py:41: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
# epoch = 0, i = 100, loss = -0.145143523812294,
# epoch = 0, i = 200, loss = -0.045947037637233734,
# epoch = 0, i = 300, loss = -0.016431093215942383,
# epoch = 0, i = 400, loss = -0.05430900678038597,
# epoch = 0, i = 500, loss = -0.0850566029548645,
# epoch = 0, i = 600, loss = 0.08252079784870148,
# epoch = 0, i = 700, loss = -0.03528562933206558,
# epoch = 0, i = 800, loss = 0.00215788371860981,
# epoch = 0, i = 900, loss = -0.07773107290267944,
# epoch = 0, i = 1000, loss = 0.02449709363281727,
# epoch = 0, i = 1100, loss = 0.03509727120399475,
# epoch = 0, i = 1200, loss = 0.0007887259125709534,
# epoch = 0, i = 1300, loss = -0.06152818351984024,
# evaluating model on dev and test...
# dev_acc: 0.3994637131690979, dev_rmse: 3.288179874420166
# test_acc: 0.3989199995994568, test_rmse: 3.076686382293701
# learning rate is 0.000495
# epoch = 1, i = 0, loss = -0.04450586065649986,
# epoch = 1, i = 100, loss = -0.0965864360332489,
# epoch = 1, i = 200, loss = -0.0027171634137630463,
# epoch = 1, i = 300, loss = 0.0592605285346508,
# epoch = 1, i = 400, loss = -0.088100366294384,
# epoch = 1, i = 500, loss = -0.04611095041036606,
# epoch = 1, i = 600, loss = 0.13060709834098816,
# epoch = 1, i = 700, loss = -0.09678583592176437,
# epoch = 1, i = 800, loss = -0.12132212519645691,
# epoch = 1, i = 900, loss = -0.05178866535425186,
# epoch = 1, i = 1000, loss = -0.12756474316120148,
# epoch = 1, i = 1100, loss = -0.08837145566940308,
# epoch = 1, i = 1200, loss = 0.005333328619599342,
# epoch = 1, i = 1300, loss = 0.0005556941032409668,
# evaluating model on dev and test...
# dev_acc: 0.4264705777168274, dev_rmse: 3.0770375728607178
# test_acc: 0.41912001371383667, test_rmse: 2.8297348022460938
# learning rate is 0.00049005
# epoch = 2, i = 0, loss = 0.001286529004573822,
# epoch = 2, i = 100, loss = 0.0370311439037323,
# epoch = 2, i = 200, loss = -0.14639145135879517,
# epoch = 2, i = 300, loss = -0.10313548147678375,
# epoch = 2, i = 400, loss = -0.08205023407936096,
# epoch = 2, i = 500, loss = 0.004775380715727806,
# epoch = 2, i = 600, loss = 0.006625998765230179,
# epoch = 2, i = 700, loss = -0.02283639647066593,
# epoch = 2, i = 800, loss = -0.003709200769662857,
# epoch = 2, i = 900, loss = 0.027318309992551804,
# epoch = 2, i = 1000, loss = -0.3790009617805481,
# epoch = 2, i = 1100, loss = -0.05079690366983414,
# epoch = 2, i = 1200, loss = -0.030471349135041237,
# epoch = 2, i = 1300, loss = -0.027044640854001045,
# evaluating model on dev and test...
# dev_acc: 0.4342440962791443, dev_rmse: 3.0112226009368896
# test_acc: 0.4325000047683716, test_rmse: 2.7650678157806396
# learning rate is 0.00048514950000000005
# epoch = 3, i = 0, loss = -0.011979253962635994,
# epoch = 3, i = 100, loss = -0.06768535077571869,
# epoch = 3, i = 200, loss = 0.016894014552235603,
# epoch = 3, i = 300, loss = -0.0400153249502182,
# epoch = 3, i = 400, loss = 0.07900761067867279,
# epoch = 3, i = 500, loss = -0.029174482449889183,
# epoch = 3, i = 600, loss = -0.015865739434957504,
# epoch = 3, i = 700, loss = -0.10063352435827255,
# epoch = 3, i = 800, loss = -0.05602262541651726,
# epoch = 3, i = 900, loss = -0.06868144124746323,
# epoch = 3, i = 1000, loss = 0.02414405718445778,
# epoch = 3, i = 1100, loss = -0.11146584153175354,
# epoch = 3, i = 1200, loss = -0.03261824697256088,
# epoch = 3, i = 1300, loss = -0.06441579759120941,
# evaluating model on dev and test...
# dev_acc: 0.4461725056171417, dev_rmse: 2.9537570476531982
# test_acc: 0.4456599950790405, test_rmse: 2.6801493167877197
# learning rate is 0.00048029800499999997
# epoch = 4, i = 0, loss = 0.05722566694021225,
# epoch = 4, i = 100, loss = -0.03223995119333267,
# epoch = 4, i = 200, loss = 0.014208976179361343,
# epoch = 4, i = 300, loss = -0.015763571485877037,
# epoch = 4, i = 400, loss = -0.05988628417253494,
# epoch = 4, i = 500, loss = -0.01701796054840088,
# epoch = 4, i = 600, loss = -0.014538994058966637,
# epoch = 4, i = 700, loss = 0.014774428680539131,
# epoch = 4, i = 800, loss = -0.036997370421886444,
# epoch = 4, i = 900, loss = -0.08506858348846436,
# epoch = 4, i = 1000, loss = -0.06449014693498611,
# epoch = 4, i = 1100, loss = -0.03916800767183304,
# epoch = 4, i = 1200, loss = -0.04439471662044525,
# epoch = 4, i = 1300, loss = -0.03458988666534424,
# evaluating model on dev and test...
# dev_acc: 0.45753639936447144, dev_rmse: 2.9778640270233154
# test_acc: 0.46059998869895935, test_rmse: 2.7093911170959473
# learning rate is 0.00047549502494999995
# epoch = 5, i = 0, loss = -0.05064709484577179,
# epoch = 5, i = 100, loss = -0.0458531379699707,
# epoch = 5, i = 200, loss = 0.002538071945309639,
# epoch = 5, i = 300, loss = -0.00039306096732616425,
# epoch = 5, i = 400, loss = -0.021016264334321022,
# epoch = 5, i = 500, loss = 0.0019183754920959473,
# epoch = 5, i = 600, loss = 0.004813395440578461,
# epoch = 5, i = 700, loss = -0.10525685548782349,
# epoch = 5, i = 800, loss = -0.11337924003601074,
# epoch = 5, i = 900, loss = -0.060684897005558014,
# epoch = 5, i = 1000, loss = -0.010294603183865547,
# epoch = 5, i = 1100, loss = -0.0051875244826078415,
# epoch = 5, i = 1200, loss = -0.1066155731678009,
# epoch = 5, i = 1300, loss = -0.002878459170460701,
# evaluating model on dev and test...
# dev_acc: 0.46634864807128906, dev_rmse: 2.921443223953247
# test_acc: 0.4711399972438812, test_rmse: 2.6475272178649902
# learning rate is 0.0004707400747005
# epoch = 6, i = 0, loss = -0.042404256761074066,
# epoch = 6, i = 100, loss = -0.00462079793214798,
# epoch = 6, i = 200, loss = -0.07229670137166977,
# epoch = 6, i = 300, loss = 0.000606294721364975,
# epoch = 6, i = 400, loss = -0.08573295176029205,
# epoch = 6, i = 500, loss = -0.011926468461751938,
# epoch = 6, i = 600, loss = -0.07208211719989777,
# epoch = 6, i = 700, loss = -0.011110179126262665,
# epoch = 6, i = 800, loss = -0.01950344443321228,
# epoch = 6, i = 900, loss = 0.013155736960470676,
# epoch = 6, i = 1000, loss = -0.08897572755813599,
# epoch = 6, i = 1100, loss = -0.07363923639059067,
# epoch = 6, i = 1200, loss = 0.018211646005511284,
# epoch = 6, i = 1300, loss = -0.02775072678923607,
# evaluating model on dev and test...
# dev_acc: 0.4727785885334015, dev_rmse: 2.8802742958068848
# test_acc: 0.4802600145339966, test_rmse: 2.6100192070007324
# learning rate is 0.00046603267395349497
# epoch = 7, i = 0, loss = -0.046699587255716324,
# epoch = 7, i = 100, loss = -0.008725807070732117,
# epoch = 7, i = 200, loss = -0.039629220962524414,
# epoch = 7, i = 300, loss = -0.02824268862605095,
# epoch = 7, i = 400, loss = -0.01577679067850113,
# epoch = 7, i = 500, loss = 0.04359414055943489,
# epoch = 7, i = 600, loss = -0.08957496285438538,
# epoch = 7, i = 700, loss = -0.027824843302369118,
# epoch = 7, i = 800, loss = -0.10309218615293503,
# epoch = 7, i = 900, loss = -0.04051900655031204,
# epoch = 7, i = 1000, loss = 0.022999675944447517,
# epoch = 7, i = 1100, loss = -0.0771133080124855,
# epoch = 7, i = 1200, loss = -0.04164097458124161,
# epoch = 7, i = 1300, loss = -0.02416132390499115,
# evaluating model on dev and test...
# dev_acc: 0.4744495749473572, dev_rmse: 2.807321548461914
# test_acc: 0.48311999440193176, test_rmse: 2.544877290725708
# learning rate is 0.00046137234721396004
# epoch = 8, i = 0, loss = -0.04431368038058281,
# epoch = 8, i = 100, loss = -0.018304577097296715,
# epoch = 8, i = 200, loss = -0.07313413918018341,
# epoch = 8, i = 300, loss = -0.008924044668674469,
# epoch = 8, i = 400, loss = -0.08135268092155457,
# epoch = 8, i = 500, loss = 0.052297770977020264,
# epoch = 8, i = 600, loss = -0.0035569611936807632,
# epoch = 8, i = 700, loss = -0.0652812272310257,
# epoch = 8, i = 800, loss = -0.04669491946697235,
# epoch = 8, i = 900, loss = -0.031161058694124222,
# epoch = 8, i = 1000, loss = -0.03250088542699814,
# epoch = 8, i = 1100, loss = -0.006224749609827995,
# epoch = 8, i = 1200, loss = 0.008830702863633633,
# epoch = 8, i = 1300, loss = -0.02521960809826851,
# evaluating model on dev and test...
# dev_acc: 0.48400136828422546, dev_rmse: 2.795916795730591
# test_acc: 0.48947998881340027, test_rmse: 2.521864414215088
# learning rate is 0.00045675862374182043
# epoch = 9, i = 0, loss = -0.011339575052261353,
# epoch = 9, i = 100, loss = -0.03959771245718002,
# epoch = 9, i = 200, loss = -0.022601092234253883,
# epoch = 9, i = 300, loss = -0.03710179030895233,
# epoch = 9, i = 400, loss = 0.044361796230077744,
# epoch = 9, i = 500, loss = -0.08616495132446289,
# epoch = 9, i = 600, loss = 0.008093796670436859,
# epoch = 9, i = 700, loss = -0.043922509998083115,
# epoch = 9, i = 800, loss = -0.01657542586326599,
# epoch = 9, i = 900, loss = 0.012701405212283134,
# epoch = 9, i = 1000, loss = 0.008855561725795269,
# epoch = 9, i = 1100, loss = -0.030450114980340004,
# epoch = 9, i = 1200, loss = 0.015750844031572342,
# epoch = 9, i = 1300, loss = -0.05025618150830269,
# evaluating model on dev and test...
# dev_acc: 0.4850739538669586, dev_rmse: 2.802299976348877
# test_acc: 0.49248000979423523, test_rmse: 2.559257745742798
# learning rate is 0.0004521910375044022
# saving model..
# Done.
# epoch = 10, i = 0, loss = 0.01868540607392788,
# epoch = 10, i = 100, loss = -0.0336083248257637,
# epoch = 10, i = 200, loss = -0.034114524722099304,
# epoch = 10, i = 300, loss = -0.017372826114296913,
# epoch = 10, i = 400, loss = -0.07143858820199966,
# epoch = 10, i = 500, loss = 0.0022318996489048004,
# epoch = 10, i = 600, loss = 0.006267305463552475,
# epoch = 10, i = 700, loss = -0.03275662660598755,
# epoch = 10, i = 800, loss = -0.09717507660388947,
# epoch = 10, i = 900, loss = -0.005088701844215393,
# epoch = 10, i = 1000, loss = 0.06885654479265213,
# epoch = 10, i = 1100, loss = 0.00952475517988205,
# epoch = 10, i = 1200, loss = -0.018186070024967194,
# epoch = 10, i = 1300, loss = -0.03858184069395065,
# evaluating model on dev and test...
# dev_acc: 0.4870046377182007, dev_rmse: 2.804283618927002
# test_acc: 0.4968799948692322, test_rmse: 2.5465662479400635
# learning rate is 0.0004476691271293582
# epoch = 11, i = 0, loss = -0.04550491273403168,
# epoch = 11, i = 100, loss = 0.013223199173808098,
# epoch = 11, i = 200, loss = -0.027806082740426064,
# epoch = 11, i = 300, loss = 0.026168953627347946,
# epoch = 11, i = 400, loss = 0.014053070917725563,
# epoch = 11, i = 500, loss = 0.020630890503525734,
# epoch = 11, i = 600, loss = -0.09675270318984985,
# epoch = 11, i = 700, loss = -0.01051411870867014,
# epoch = 11, i = 800, loss = -0.050752412527799606,
# epoch = 11, i = 900, loss = 0.034591156989336014,
# epoch = 11, i = 1000, loss = 0.007883143611252308,
# epoch = 11, i = 1100, loss = -0.019841007888317108,
# epoch = 11, i = 1200, loss = -0.0643187165260315,
# epoch = 11, i = 1300, loss = -0.08311916142702103,
# evaluating model on dev and test...
# dev_acc: 0.4912159740924835, dev_rmse: 2.8003249168395996
# test_acc: 0.5039799809455872, test_rmse: 2.502798318862915
# learning rate is 0.0004431924358580646
# epoch = 12, i = 0, loss = -0.018304476514458656,
# epoch = 12, i = 100, loss = -0.013963261619210243,
# epoch = 12, i = 200, loss = -0.028423484414815903,
# epoch = 12, i = 300, loss = -0.030086833983659744,
# epoch = 12, i = 400, loss = -0.019867070019245148,
# epoch = 12, i = 500, loss = 0.0022771377116441727,
# epoch = 12, i = 600, loss = 0.0017444426193833351,
# epoch = 12, i = 700, loss = 0.047453977167606354,
# epoch = 12, i = 800, loss = -0.012026887387037277,
# epoch = 12, i = 900, loss = 0.011113099753856659,
# epoch = 12, i = 1000, loss = -0.06993968784809113,
# epoch = 12, i = 1100, loss = 0.015513688325881958,
# epoch = 12, i = 1200, loss = -0.0217518862336874,
# epoch = 12, i = 1300, loss = -0.07921558618545532,
# evaluating model on dev and test...
# dev_acc: 0.49306198954582214, dev_rmse: 2.7749199867248535
# test_acc: 0.5013599991798401, test_rmse: 2.5268161296844482
# learning rate is 0.00043876051149948394
# epoch = 13, i = 0, loss = -0.02326335571706295,
# epoch = 13, i = 100, loss = 0.003098219633102417,
# epoch = 13, i = 200, loss = -0.13590115308761597,
# epoch = 13, i = 300, loss = -0.05542880296707153,
# epoch = 13, i = 400, loss = -0.0578901581466198,
# epoch = 13, i = 500, loss = 0.01447689812630415,
# epoch = 13, i = 600, loss = 0.010401877574622631,
# epoch = 13, i = 700, loss = -0.06689678132534027,
# epoch = 13, i = 800, loss = -0.052283115684986115,
# epoch = 13, i = 900, loss = -0.0017056874930858612,
# epoch = 13, i = 1000, loss = -0.015755340456962585,
# epoch = 13, i = 1100, loss = -0.037789300084114075,
# epoch = 13, i = 1200, loss = -0.034482814371585846,
# epoch = 13, i = 1300, loss = 0.01459069550037384,
# evaluating model on dev and test...
# dev_acc: 0.4934232831001282, dev_rmse: 2.8170676231384277
# test_acc: 0.5065799951553345, test_rmse: 2.5332982540130615
# learning rate is 0.00043437290638448915
# epoch = 14, i = 0, loss = -0.07368988543748856,
# epoch = 14, i = 100, loss = -0.02083875797688961,
# epoch = 14, i = 200, loss = -0.03597891330718994,
# epoch = 14, i = 300, loss = -0.019386975094676018,
# epoch = 14, i = 400, loss = 0.02891497313976288,
# epoch = 14, i = 500, loss = -0.0211119893938303,
# epoch = 14, i = 600, loss = -0.01797219179570675,
# epoch = 14, i = 700, loss = 0.0013102265074849129,
# epoch = 14, i = 800, loss = -0.07143621891736984,
# epoch = 14, i = 900, loss = -0.006869865581393242,
# epoch = 14, i = 1000, loss = -0.03777594119310379,
# epoch = 14, i = 1100, loss = -0.02116907387971878,
# epoch = 14, i = 1200, loss = -0.048605527728796005,
# epoch = 14, i = 1300, loss = -0.024570509791374207,
# evaluating model on dev and test...
# dev_acc: 0.49190470576286316, dev_rmse: 2.7319154739379883
# test_acc: 0.5085800290107727, test_rmse: 2.442007303237915
# learning rate is 0.00043002917732064424
# epoch = 15, i = 0, loss = -0.06855711340904236,
# epoch = 15, i = 100, loss = -0.023566951975226402,
# epoch = 15, i = 200, loss = -0.09429042786359787,
# epoch = 15, i = 300, loss = -0.048675570636987686,
# epoch = 15, i = 400, loss = -0.016655031591653824,
# epoch = 15, i = 500, loss = -0.0006568916141986847,
# epoch = 15, i = 600, loss = -0.015081066638231277,
# epoch = 15, i = 700, loss = -0.012856598943471909,
# epoch = 15, i = 800, loss = 0.010479534044861794,
# epoch = 15, i = 900, loss = 0.008943681605160236,
# epoch = 15, i = 1000, loss = -0.042208049446344376,
# epoch = 15, i = 1100, loss = -0.06343021988868713,
# epoch = 15, i = 1200, loss = 0.009433761239051819,
# epoch = 15, i = 1300, loss = -0.07645252346992493,
# evaluating model on dev and test...
# dev_acc: 0.4979451298713684, dev_rmse: 2.7841203212738037
# test_acc: 0.5137199759483337, test_rmse: 2.506232261657715
# learning rate is 0.0004257288855474378
# epoch = 16, i = 0, loss = -0.002011949196457863,
# epoch = 16, i = 100, loss = -0.07687166333198547,
# epoch = 16, i = 200, loss = -0.033016279339790344,
# epoch = 16, i = 300, loss = -0.029992736876010895,
# epoch = 16, i = 400, loss = -0.04744227975606918,
# epoch = 16, i = 500, loss = -0.030322114005684853,
# epoch = 16, i = 600, loss = -0.03365148603916168,
# epoch = 16, i = 700, loss = -0.4992859363555908,
# epoch = 16, i = 800, loss = -0.03714150935411453,
# epoch = 16, i = 900, loss = 0.013146982528269291,
# epoch = 16, i = 1000, loss = -0.06381025910377502,
# epoch = 16, i = 1100, loss = -0.055391743779182434,
# epoch = 16, i = 1200, loss = 0.009310225956141949,
# epoch = 16, i = 1300, loss = -0.020347321406006813,
# evaluating model on dev and test...
# dev_acc: 0.499949187040329, dev_rmse: 2.7200698852539062
# test_acc: 0.5156199932098389, test_rmse: 2.437703847885132
# learning rate is 0.0004214715966919634
# epoch = 17, i = 0, loss = -0.06459788233041763,
# epoch = 17, i = 100, loss = -0.00311896950006485,
# epoch = 17, i = 200, loss = -0.0028237737715244293,
# epoch = 17, i = 300, loss = -0.05708535015583038,
# epoch = 17, i = 400, loss = -0.00782998651266098,
# epoch = 17, i = 500, loss = -0.06356898695230484,
# epoch = 17, i = 600, loss = -0.03673053905367851,
# epoch = 17, i = 700, loss = -0.005960725247859955,
# epoch = 17, i = 800, loss = -0.018289361149072647,
# epoch = 17, i = 900, loss = -0.05656662583351135,
# epoch = 17, i = 1000, loss = -0.004293549805879593,
# epoch = 17, i = 1100, loss = -0.006936240941286087,
# epoch = 17, i = 1200, loss = -0.05469953641295433,
# epoch = 17, i = 1300, loss = -0.012331224977970123,
# evaluating model on dev and test...
# dev_acc: 0.5000338554382324, dev_rmse: 2.74018931388855
# test_acc: 0.5157600045204163, test_rmse: 2.41789174079895
# learning rate is 0.00041725688072504375
# epoch = 18, i = 0, loss = 0.0006249044090509415,
# epoch = 18, i = 100, loss = 0.06318235397338867,
# epoch = 18, i = 200, loss = -0.10617832839488983,
# epoch = 18, i = 300, loss = -0.04658662527799606,
# epoch = 18, i = 400, loss = -0.03139791637659073,
# epoch = 18, i = 500, loss = 0.0011899936944246292,
# epoch = 18, i = 600, loss = -0.06361262500286102,
# epoch = 18, i = 700, loss = 0.006890059448778629,
# epoch = 18, i = 800, loss = -0.0042840586975216866,
# epoch = 18, i = 900, loss = -0.06500133126974106,
# epoch = 18, i = 1000, loss = -0.0053459350019693375,
# epoch = 18, i = 1100, loss = -0.014356705360114574,
# epoch = 18, i = 1200, loss = -0.05406222492456436,
# epoch = 18, i = 1300, loss = -0.04093381017446518,
# evaluating model on dev and test...
# dev_acc: 0.5031331181526184, dev_rmse: 2.7176926136016846
# test_acc: 0.5157399773597717, test_rmse: 2.428662061691284
# learning rate is 0.00041308431191779333
# epoch = 19, i = 0, loss = -0.017954694107174873,
# epoch = 19, i = 100, loss = -0.07849812507629395,
# epoch = 19, i = 200, loss = -0.0751354843378067,
# epoch = 19, i = 300, loss = -0.03401581197977066,
# epoch = 19, i = 400, loss = -0.06277039647102356,
# epoch = 19, i = 500, loss = -0.021672990173101425,
# epoch = 19, i = 600, loss = -0.046307358890771866,
# epoch = 19, i = 700, loss = -0.022844599559903145,
# epoch = 19, i = 800, loss = 0.010144227184355259,
# epoch = 19, i = 900, loss = 0.005716989748179913,
# epoch = 19, i = 1000, loss = 0.03554863482713699,
# epoch = 19, i = 1100, loss = 0.00026326440274715424,
# epoch = 19, i = 1200, loss = -0.03771402686834335,
# epoch = 19, i = 1300, loss = -0.01841953583061695,
# evaluating model on dev and test...
# dev_acc: 0.5021395683288574, dev_rmse: 2.7509429454803467
# test_acc: 0.5178999900817871, test_rmse: 2.4748332500457764
# learning rate is 0.00040895346879861536
# saving model..
# Done.
# epoch = 20, i = 0, loss = -0.005638983100652695,
# epoch = 20, i = 100, loss = -0.048121728003025055,
# epoch = 20, i = 200, loss = -0.051727376878261566,
# epoch = 20, i = 300, loss = -0.06448528915643692,
# epoch = 20, i = 400, loss = 0.02161484584212303,
# epoch = 20, i = 500, loss = -0.02571355551481247,
# epoch = 20, i = 600, loss = -0.04570833593606949,
# epoch = 20, i = 700, loss = -0.024185871705412865,
# epoch = 20, i = 800, loss = -0.027052927762269974,
# epoch = 20, i = 900, loss = 0.0033132052049040794,
# epoch = 20, i = 1000, loss = -0.012913290411233902,
# epoch = 20, i = 1100, loss = -0.014073511585593224,
# epoch = 20, i = 1200, loss = -0.02012033760547638,
# epoch = 20, i = 1300, loss = 0.006594717502593994,
# evaluating model on dev and test...
# dev_acc: 0.5012419819831848, dev_rmse: 2.741126537322998
# test_acc: 0.5186200141906738, test_rmse: 2.463777542114258
# learning rate is 0.0004048639341106292
# epoch = 21, i = 0, loss = 0.004758210852742195,
# epoch = 21, i = 100, loss = 0.005636752583086491,
# epoch = 21, i = 200, loss = 0.012848485261201859,
# epoch = 21, i = 300, loss = -0.040204983204603195,
# epoch = 21, i = 400, loss = -0.015781361609697342,
# epoch = 21, i = 500, loss = -0.007975941523909569,
# epoch = 21, i = 600, loss = -0.022205296903848648,
# epoch = 21, i = 700, loss = 0.01129390113055706,
# epoch = 21, i = 800, loss = -0.013154537416994572,
# epoch = 21, i = 900, loss = -0.026409566402435303,
# epoch = 21, i = 1000, loss = -0.016902104020118713,
# epoch = 21, i = 1100, loss = 0.01522266585379839,
# epoch = 21, i = 1200, loss = -0.08612744510173798,
# epoch = 21, i = 1300, loss = -0.03381212800741196,
# evaluating model on dev and test...
# dev_acc: 0.5059557557106018, dev_rmse: 2.7332067489624023
# test_acc: 0.5251200199127197, test_rmse: 2.4277560710906982
# learning rate is 0.0004008152947695229
# epoch = 22, i = 0, loss = 0.06232285499572754,
# epoch = 22, i = 100, loss = -0.04109805077314377,
# epoch = 22, i = 200, loss = -0.05019676312804222,
# epoch = 22, i = 300, loss = 0.022592585533857346,
# epoch = 22, i = 400, loss = -0.015532560646533966,
# epoch = 22, i = 500, loss = 0.002884344197809696,
# epoch = 22, i = 600, loss = -0.022859793156385422,
# epoch = 22, i = 700, loss = -0.0675588995218277,
# epoch = 22, i = 800, loss = -0.061468951404094696,
# epoch = 22, i = 900, loss = -0.03472420573234558,
# epoch = 22, i = 1000, loss = -0.017981158569455147,
# epoch = 22, i = 1100, loss = -0.0005006343126296997,
# epoch = 22, i = 1200, loss = -0.039777517318725586,
# epoch = 22, i = 1300, loss = -0.05799711495637894,
# evaluating model on dev and test...
# dev_acc: 0.5047081708908081, dev_rmse: 2.7231087684631348
# test_acc: 0.5184000134468079, test_rmse: 2.4334750175476074
# learning rate is 0.0003968071418218277
# epoch = 23, i = 0, loss = -0.09140636026859283,
# epoch = 23, i = 100, loss = 0.006970233283936977,
# epoch = 23, i = 200, loss = -0.009715341031551361,
# epoch = 23, i = 300, loss = -0.04887842386960983,
# epoch = 23, i = 400, loss = -0.03831057250499725,
# epoch = 23, i = 500, loss = -0.015055280178785324,
# epoch = 23, i = 600, loss = -0.007454040460288525,
# epoch = 23, i = 700, loss = -0.004459925927221775,
# epoch = 23, i = 800, loss = -0.05415574461221695,
# epoch = 23, i = 900, loss = -0.015457544475793839,
# epoch = 23, i = 1000, loss = -0.06796269863843918,
# epoch = 23, i = 1100, loss = -0.04187425225973129,
# epoch = 23, i = 1200, loss = -0.01791154220700264,
# epoch = 23, i = 1300, loss = -0.09074091166257858,
# evaluating model on dev and test...
# dev_acc: 0.5048266649246216, dev_rmse: 2.7383859157562256
# test_acc: 0.5278800129890442, test_rmse: 2.427509069442749
# learning rate is 0.0003928390704036094
# epoch = 24, i = 0, loss = -0.035729795694351196,
# epoch = 24, i = 100, loss = -0.02270255982875824,
# epoch = 24, i = 200, loss = -0.07242751866579056,
# epoch = 24, i = 300, loss = -0.041076675057411194,
# epoch = 24, i = 400, loss = -0.03430723026394844,
# epoch = 24, i = 500, loss = 0.010918422602117062,
# epoch = 24, i = 600, loss = -0.13993896543979645,
# epoch = 24, i = 700, loss = -0.01867130771279335,
# epoch = 24, i = 800, loss = 0.028034720569849014,
# epoch = 24, i = 900, loss = -0.005166640505194664,
# epoch = 24, i = 1000, loss = -0.02568882890045643,
# epoch = 24, i = 1100, loss = -0.036029472947120667,
# epoch = 24, i = 1200, loss = -0.021312326192855835,
# epoch = 24, i = 1300, loss = -0.037347838282585144,
# evaluating model on dev and test...
# dev_acc: 0.504877507686615, dev_rmse: 2.7115371227264404
# test_acc: 0.5183799862861633, test_rmse: 2.448183059692383
# learning rate is 0.00038891067969957333
# epoch = 25, i = 0, loss = -0.01622786559164524,
# epoch = 25, i = 100, loss = -0.08699380606412888,
# epoch = 25, i = 200, loss = -0.08600802719593048,
# epoch = 25, i = 300, loss = -0.04907737672328949,
# epoch = 25, i = 400, loss = -0.004600042477250099,
# epoch = 25, i = 500, loss = -0.02075638435781002,
# epoch = 25, i = 600, loss = -0.01740299165248871,
# epoch = 25, i = 700, loss = 0.007664483971893787,
# epoch = 25, i = 800, loss = -0.02733529731631279,
# epoch = 25, i = 900, loss = -0.05557829141616821,
# epoch = 25, i = 1000, loss = -0.03442675620317459,
# epoch = 25, i = 1100, loss = 0.022171545773744583,
# epoch = 25, i = 1200, loss = -0.006824941374361515,
# epoch = 25, i = 1300, loss = -0.047261204570531845,
# evaluating model on dev and test...
# dev_acc: 0.5065202713012695, dev_rmse: 2.7597527503967285
# test_acc: 0.518500030040741, test_rmse: 2.4891364574432373
# learning rate is 0.0003850215729025776
# epoch = 26, i = 0, loss = -0.010731764137744904,
# epoch = 26, i = 100, loss = -0.02101694978773594,
# epoch = 26, i = 200, loss = 0.06452695280313492,
# epoch = 26, i = 300, loss = 0.003231992945075035,
# epoch = 26, i = 400, loss = -0.027380088344216347,
# epoch = 26, i = 500, loss = -0.04962776601314545,
# epoch = 26, i = 600, loss = -0.0074579063802957535,
# epoch = 26, i = 700, loss = -0.04804995656013489,
# epoch = 26, i = 800, loss = 0.003129522316157818,
# epoch = 26, i = 900, loss = 0.00885425228625536,
# epoch = 26, i = 1000, loss = -0.04319389909505844,
# epoch = 26, i = 1100, loss = -0.00597325898706913,
# epoch = 26, i = 1200, loss = -0.01959632709622383,
# epoch = 26, i = 1300, loss = -0.035951025784015656,
# evaluating model on dev and test...
# dev_acc: 0.5089872479438782, dev_rmse: 2.722517967224121
# test_acc: 0.528980016708374, test_rmse: 2.4434401988983154
# learning rate is 0.0003811713571735518
# epoch = 27, i = 0, loss = 0.03022173047065735,
# epoch = 27, i = 100, loss = -0.024506691843271255,
# epoch = 27, i = 200, loss = -0.012965911068022251,
# epoch = 27, i = 300, loss = -0.05479660630226135,
# epoch = 27, i = 400, loss = -0.03427673503756523,
# epoch = 27, i = 500, loss = 0.00798072386533022,
# epoch = 27, i = 600, loss = -0.03335874155163765,
# epoch = 27, i = 700, loss = -0.10537193715572357,
# epoch = 27, i = 800, loss = -0.002230629324913025,
# epoch = 27, i = 900, loss = 0.004716183990240097,
# epoch = 27, i = 1000, loss = 0.01300974003970623,
# epoch = 27, i = 1100, loss = -0.039398789405822754,
# epoch = 27, i = 1200, loss = -0.013105392456054688,
# epoch = 27, i = 1300, loss = -0.018434884026646614,
# evaluating model on dev and test...
# dev_acc: 0.5058541297912598, dev_rmse: 2.747904062271118
# test_acc: 0.5290600061416626, test_rmse: 2.469534397125244
# learning rate is 0.0003773596436018163
# epoch = 28, i = 0, loss = -0.07565617561340332,
# epoch = 28, i = 100, loss = -0.011613212525844574,
# epoch = 28, i = 200, loss = -0.020312421023845673,
# epoch = 28, i = 300, loss = 0.009708323515951633,
# epoch = 28, i = 400, loss = -0.03567878156900406,
# epoch = 28, i = 500, loss = -0.020723599940538406,
# epoch = 28, i = 600, loss = -0.023331794887781143,
# epoch = 28, i = 700, loss = -0.013431837782263756,
# epoch = 28, i = 800, loss = -0.0037353895604610443,
# epoch = 28, i = 900, loss = -0.005943372845649719,
# epoch = 28, i = 1000, loss = -0.03963933885097504,
# epoch = 28, i = 1100, loss = 0.014241203665733337,
# epoch = 28, i = 1200, loss = 0.014251266606152058,
# epoch = 28, i = 1300, loss = -0.13101226091384888,
# evaluating model on dev and test...
# dev_acc: 0.5108783841133118, dev_rmse: 2.6917803287506104
# test_acc: 0.5281000137329102, test_rmse: 2.422354221343994
# learning rate is 0.0003735860471657981
# epoch = 29, i = 0, loss = -0.06246616691350937,
# epoch = 29, i = 100, loss = -0.048788607120513916,
# epoch = 29, i = 200, loss = -0.019312560558319092,
# epoch = 29, i = 300, loss = 0.027839727699756622,
# epoch = 29, i = 400, loss = -0.054333798587322235,
# epoch = 29, i = 500, loss = 0.004660140722990036,
# epoch = 29, i = 600, loss = -0.020907867699861526,
# epoch = 29, i = 700, loss = 0.03463762253522873,
# epoch = 29, i = 800, loss = 0.02664826810359955,
# epoch = 29, i = 900, loss = -0.010968295857310295,
# epoch = 29, i = 1000, loss = -0.00412772037088871,
# epoch = 29, i = 1100, loss = 0.014184251427650452,
# epoch = 29, i = 1200, loss = -0.050160542130470276,
# epoch = 29, i = 1300, loss = -0.02416440285742283,
# evaluating model on dev and test...
# dev_acc: 0.5082589983940125, dev_rmse: 2.719540596008301
# test_acc: 0.5280799865722656, test_rmse: 2.4781041145324707
# learning rate is 0.0003698501866941401
# saving model..
# Done.
# epoch = 30, i = 0, loss = -0.0480097271502018,
# epoch = 30, i = 100, loss = -0.045036494731903076,
# epoch = 30, i = 200, loss = -0.03646194189786911,
# epoch = 30, i = 300, loss = -0.020998355001211166,
# epoch = 30, i = 400, loss = -0.05423613265156746,
# epoch = 30, i = 500, loss = -0.046990618109703064,
# epoch = 30, i = 600, loss = -0.01918349415063858,
# epoch = 30, i = 700, loss = -0.006157999858260155,
# epoch = 30, i = 800, loss = -0.042422711849212646,
# epoch = 30, i = 900, loss = -0.0224822498857975,
# epoch = 30, i = 1000, loss = -0.01742415875196457,
# epoch = 30, i = 1100, loss = -0.032997339963912964,
# epoch = 30, i = 1200, loss = -0.03271261602640152,
# epoch = 30, i = 1300, loss = -0.037802357226610184,
# evaluating model on dev and test...
# dev_acc: 0.5118775963783264, dev_rmse: 2.6961286067962646
# test_acc: 0.5327799916267395, test_rmse: 2.423551082611084
# learning rate is 0.00036615168482719875
# epoch = 31, i = 0, loss = -0.02126566879451275,
# epoch = 31, i = 100, loss = -0.032753217965364456,
# epoch = 31, i = 200, loss = -0.02515207603573799,
# epoch = 31, i = 300, loss = -0.058175597339868546,
# epoch = 31, i = 400, loss = 0.002883637323975563,
# epoch = 31, i = 500, loss = -0.02539946883916855,
# epoch = 31, i = 600, loss = 0.003578193485736847,
# epoch = 31, i = 700, loss = -0.02371920645236969,
# epoch = 31, i = 800, loss = -0.0016124751418828964,
# epoch = 31, i = 900, loss = -0.0761478841304779,
# epoch = 31, i = 1000, loss = 0.006929207593202591,
# epoch = 31, i = 1100, loss = -0.018460847437381744,
# epoch = 31, i = 1200, loss = -0.00948495976626873,
# epoch = 31, i = 1300, loss = 0.02292809635400772,
# evaluating model on dev and test...
# dev_acc: 0.5095009803771973, dev_rmse: 2.7010445594787598
# test_acc: 0.5276600122451782, test_rmse: 2.449040651321411
# learning rate is 0.0003624901679789267
# epoch = 32, i = 0, loss = -0.05069055035710335,
# epoch = 32, i = 100, loss = -0.040991850197315216,
# epoch = 32, i = 200, loss = 0.01681213080883026,
# epoch = 32, i = 300, loss = 0.01665748655796051,
# epoch = 32, i = 400, loss = -0.04591205343604088,
# epoch = 32, i = 500, loss = -0.022580768913030624,
# epoch = 32, i = 600, loss = -0.0520934984087944,
# epoch = 32, i = 700, loss = 0.0006945496425032616,
# epoch = 32, i = 800, loss = 0.021127061918377876,
# epoch = 32, i = 900, loss = -0.0238184854388237,
# epoch = 32, i = 1000, loss = -0.0126443300396204,
# epoch = 32, i = 1100, loss = -0.010694647207856178,
# epoch = 32, i = 1200, loss = -0.005345272831618786,
# epoch = 32, i = 1300, loss = -0.001380421221256256,
# evaluating model on dev and test...
# dev_acc: 0.5116009712219238, dev_rmse: 2.737478733062744
# test_acc: 0.5258200168609619, test_rmse: 2.4549949169158936
# learning rate is 0.00035886526629913746
# epoch = 33, i = 0, loss = -0.023282039910554886,
# epoch = 33, i = 100, loss = -0.013108081184327602,
# epoch = 33, i = 200, loss = -0.06050383672118187,
# epoch = 33, i = 300, loss = -0.2401985228061676,
# epoch = 33, i = 400, loss = 0.0013119177892804146,
# epoch = 33, i = 500, loss = -0.005555653013288975,
# epoch = 33, i = 600, loss = -0.030095107853412628,
# epoch = 33, i = 700, loss = 0.017033902928233147,
# epoch = 33, i = 800, loss = -0.016943009570240974,
# epoch = 33, i = 900, loss = -0.0701935887336731,
# epoch = 33, i = 1000, loss = 0.00026327837258577347,
# epoch = 33, i = 1100, loss = -0.03758044168353081,
# epoch = 33, i = 1200, loss = -0.029600530862808228,
# epoch = 33, i = 1300, loss = -0.03382957726716995,
# evaluating model on dev and test...
# dev_acc: 0.5115671157836914, dev_rmse: 2.7139406204223633
# test_acc: 0.5294600129127502, test_rmse: 2.449326515197754
# learning rate is 0.00035527661363614604
# epoch = 34, i = 0, loss = -0.03514065593481064,
# epoch = 34, i = 100, loss = -0.0025511905550956726,
# epoch = 34, i = 200, loss = -0.003472141921520233,
# epoch = 34, i = 300, loss = -0.017482507973909378,
# epoch = 34, i = 400, loss = -0.0414159893989563,
# epoch = 34, i = 500, loss = -0.06550043076276779,
# epoch = 34, i = 600, loss = -0.027367115020751953,
# epoch = 34, i = 700, loss = -0.013959907926619053,
# epoch = 34, i = 800, loss = 0.01257839985191822,
# epoch = 34, i = 900, loss = -0.025483479723334312,
# epoch = 34, i = 1000, loss = -0.019487567245960236,
# epoch = 34, i = 1100, loss = 0.006480522453784943,
# epoch = 34, i = 1200, loss = -0.034415874630212784,
# epoch = 34, i = 1300, loss = 0.03137702867388725,
# evaluating model on dev and test...
# dev_acc: 0.512255847454071, dev_rmse: 2.7126505374908447
# test_acc: 0.5301200151443481, test_rmse: 2.4561352729797363
# learning rate is 0.00035172384749978456
# epoch = 35, i = 0, loss = -0.029729539528489113,
# epoch = 35, i = 100, loss = 0.015691276639699936,
# epoch = 35, i = 200, loss = -0.037773266434669495,
# epoch = 35, i = 300, loss = -0.04681180417537689,
# epoch = 35, i = 400, loss = -0.02138352021574974,
# epoch = 35, i = 500, loss = -0.05167341232299805,
# epoch = 35, i = 600, loss = -0.002342010848224163,
# epoch = 35, i = 700, loss = -0.02041546069085598,
# epoch = 35, i = 800, loss = -0.037046562880277634,
# epoch = 35, i = 900, loss = 0.0021922457963228226,
# epoch = 35, i = 1000, loss = -0.05092402920126915,
# epoch = 35, i = 1100, loss = -0.030829252675175667,
# epoch = 35, i = 1200, loss = -0.00921686366200447,
# epoch = 35, i = 1300, loss = 0.011836941353976727,
# evaluating model on dev and test...
# dev_acc: 0.5111493468284607, dev_rmse: 2.730551242828369
# test_acc: 0.5314599871635437, test_rmse: 2.4628844261169434
# learning rate is 0.00034820660902478676
# epoch = 36, i = 0, loss = -0.0462118536233902,
# epoch = 36, i = 100, loss = -0.06155673786997795,
# epoch = 36, i = 200, loss = -0.021247275173664093,
# epoch = 36, i = 300, loss = -0.0391550287604332,
# epoch = 36, i = 400, loss = -0.038972124457359314,
# epoch = 36, i = 500, loss = 0.01800582930445671,
# epoch = 36, i = 600, loss = 0.02488008886575699,
# epoch = 36, i = 700, loss = -0.23844574391841888,
# epoch = 36, i = 800, loss = -0.007998298853635788,
# epoch = 36, i = 900, loss = -0.028578106313943863,
# epoch = 36, i = 1000, loss = -0.0464678592979908,
# epoch = 36, i = 1100, loss = 0.01934433914721012,
# epoch = 36, i = 1200, loss = 0.010900292545557022,
# epoch = 36, i = 1300, loss = -0.008532263338565826,
# evaluating model on dev and test...
# dev_acc: 0.5132155418395996, dev_rmse: 2.695950508117676
# test_acc: 0.5286399722099304, test_rmse: 2.417478084564209
# learning rate is 0.0003447245429345389
# epoch = 37, i = 0, loss = -0.021824155002832413,
# epoch = 37, i = 100, loss = -0.2001992017030716,
# epoch = 37, i = 200, loss = -0.03031623549759388,
# epoch = 37, i = 300, loss = -0.02917531505227089,
# epoch = 37, i = 400, loss = -0.012665405869483948,
# epoch = 37, i = 500, loss = -0.018038950860500336,
# epoch = 37, i = 600, loss = -0.02227955497801304,
# epoch = 37, i = 700, loss = 0.009936317801475525,
# epoch = 37, i = 800, loss = -0.008463053032755852,
# epoch = 37, i = 900, loss = -0.06566209346055984,
# epoch = 37, i = 1000, loss = -0.035163529217243195,
# epoch = 37, i = 1100, loss = -0.03164765238761902,
# epoch = 37, i = 1200, loss = -0.021939050406217575,
# epoch = 37, i = 1300, loss = -0.03420758247375488,
# evaluating model on dev and test...
# dev_acc: 0.5128429532051086, dev_rmse: 2.7176198959350586
# test_acc: 0.5295199751853943, test_rmse: 2.452427387237549
# learning rate is 0.00034127729750519346
# epoch = 38, i = 0, loss = -0.06154349073767662,
# epoch = 38, i = 100, loss = -0.023582953959703445,
# epoch = 38, i = 200, loss = -0.0028236713260412216,
# epoch = 38, i = 300, loss = 0.011518511921167374,
# epoch = 38, i = 400, loss = -0.03138967603445053,
# epoch = 38, i = 500, loss = -0.007274370640516281,
# epoch = 38, i = 600, loss = -0.021969188004732132,
# epoch = 38, i = 700, loss = -0.16560876369476318,
# epoch = 38, i = 800, loss = -0.019054006785154343,
# epoch = 38, i = 900, loss = -0.046026695519685745,
# epoch = 38, i = 1000, loss = -0.010708552785217762,
# epoch = 38, i = 1100, loss = -0.025576751679182053,
# epoch = 38, i = 1200, loss = -0.008207706734538078,
# epoch = 38, i = 1300, loss = -0.014458216726779938,
# evaluating model on dev and test...
# dev_acc: 0.5122389197349548, dev_rmse: 2.7060768604278564
# test_acc: 0.5345799922943115, test_rmse: 2.4454448223114014
# learning rate is 0.00033786452453014155
# epoch = 39, i = 0, loss = -0.025975985452532768,
# epoch = 39, i = 100, loss = -0.022949950769543648,
# epoch = 39, i = 200, loss = -0.009195198304951191,
# epoch = 39, i = 300, loss = -0.013864737004041672,
# epoch = 39, i = 400, loss = -0.032819923013448715,
# epoch = 39, i = 500, loss = -0.028834756463766098,
# epoch = 39, i = 600, loss = -0.01366029679775238,
# epoch = 39, i = 700, loss = 0.01345503143966198,
# epoch = 39, i = 800, loss = 0.03468925505876541,
# epoch = 39, i = 900, loss = -0.01554951723664999,
# epoch = 39, i = 1000, loss = -0.02490202523767948,
# epoch = 39, i = 1100, loss = 0.015523058362305164,
# epoch = 39, i = 1200, loss = -0.020978430286049843,
# epoch = 39, i = 1300, loss = 0.0078049651347100735,
# evaluating model on dev and test...
# dev_acc: 0.5121768116950989, dev_rmse: 2.7041046619415283
# test_acc: 0.5263599753379822, test_rmse: 2.4320361614227295
# learning rate is 0.0003344858792848401
# saving model..
# Done.
# epoch = 40, i = 0, loss = -0.07519231736660004,
# epoch = 40, i = 100, loss = 0.027786623686552048,
# epoch = 40, i = 200, loss = -0.039527494460344315,
# epoch = 40, i = 300, loss = 0.0009481906890869141,
# epoch = 40, i = 400, loss = -0.03582856059074402,
# epoch = 40, i = 500, loss = -0.06948092579841614,
# epoch = 40, i = 600, loss = -0.020297043025493622,
# epoch = 40, i = 700, loss = -0.031127363443374634,
# epoch = 40, i = 800, loss = -0.03375197574496269,
# epoch = 40, i = 900, loss = -0.006030593067407608,
# epoch = 40, i = 1000, loss = -0.005434511229395866,
# epoch = 40, i = 1100, loss = 0.0020336629822850227,
# epoch = 40, i = 1200, loss = -0.04999387264251709,
# epoch = 40, i = 1300, loss = -0.029475003480911255,
# evaluating model on dev and test...
# dev_acc: 0.5138647556304932, dev_rmse: 2.691927194595337
# test_acc: 0.5311599969863892, test_rmse: 2.443112850189209
# learning rate is 0.00033114102049199175
# epoch = 41, i = 0, loss = 0.008944382891058922,
# epoch = 41, i = 100, loss = -0.0037248199805617332,
# epoch = 41, i = 200, loss = -0.04251880943775177,
# epoch = 41, i = 300, loss = -0.04585117846727371,
# epoch = 41, i = 400, loss = -0.020339369773864746,
# epoch = 41, i = 500, loss = -0.011383689008653164,
# epoch = 41, i = 600, loss = -0.00847567804157734,
# epoch = 41, i = 700, loss = -0.03985435143113136,
# epoch = 41, i = 800, loss = -0.018763519823551178,
# epoch = 41, i = 900, loss = 0.0016900990158319473,
# epoch = 41, i = 1000, loss = -0.02513020858168602,
# epoch = 41, i = 1100, loss = -0.03466685861349106,
# epoch = 41, i = 1200, loss = -0.02529948577284813,
# epoch = 41, i = 1300, loss = -0.04461289197206497,
# evaluating model on dev and test...
# dev_acc: 0.512419581413269, dev_rmse: 2.6887900829315186
# test_acc: 0.5318999886512756, test_rmse: 2.405909538269043
# learning rate is 0.0003278296102870718
# epoch = 42, i = 0, loss = -0.025683291256427765,
# epoch = 42, i = 100, loss = -0.06174251064658165,
# epoch = 42, i = 200, loss = -0.04042694345116615,
# epoch = 42, i = 300, loss = -0.06495583802461624,
# epoch = 42, i = 400, loss = 0.02086249552667141,
# epoch = 42, i = 500, loss = 0.029610849916934967,
# epoch = 42, i = 600, loss = -0.03892634063959122,
# epoch = 42, i = 700, loss = -0.00471901148557663,
# epoch = 42, i = 800, loss = -0.005068534053862095,
# epoch = 42, i = 900, loss = -0.3555591404438019,
# epoch = 42, i = 1000, loss = -0.01810133084654808,
# epoch = 42, i = 1100, loss = -0.07680808007717133,
# epoch = 42, i = 1200, loss = -0.005384902469813824,
# epoch = 42, i = 1300, loss = -0.03264009207487106,
# evaluating model on dev and test...
# dev_acc: 0.5149147510528564, dev_rmse: 2.7144086360931396
# test_acc: 0.5285800099372864, test_rmse: 2.4376628398895264
# learning rate is 0.0003245513141842011
# epoch = 43, i = 0, loss = -0.24635937809944153,
# epoch = 43, i = 100, loss = -0.009210491552948952,
# epoch = 43, i = 200, loss = 0.008346246555447578,
# epoch = 43, i = 300, loss = -0.02990223839879036,
# epoch = 43, i = 400, loss = 0.02127102017402649,
# epoch = 43, i = 500, loss = -0.028358105570077896,
# epoch = 43, i = 600, loss = -0.06923724710941315,
# epoch = 43, i = 700, loss = -0.01548913586884737,
# epoch = 43, i = 800, loss = 0.0039845360442996025,
# epoch = 43, i = 900, loss = -0.023744912818074226,
# epoch = 43, i = 1000, loss = -0.015459765680134296,
# epoch = 43, i = 1100, loss = -0.07434781640768051,
# epoch = 43, i = 1200, loss = -0.06093239784240723,
# epoch = 43, i = 1300, loss = -0.17864593863487244,
# evaluating model on dev and test...
# dev_acc: 0.5183866024017334, dev_rmse: 2.690490245819092
# test_acc: 0.5368199944496155, test_rmse: 2.42742657661438
# learning rate is 0.00032130580104235905
# epoch = 44, i = 0, loss = 0.0004732757806777954,
# epoch = 44, i = 100, loss = -0.02668154425919056,
# epoch = 44, i = 200, loss = -0.026456255465745926,
# epoch = 44, i = 300, loss = -0.06204216182231903,
# epoch = 44, i = 400, loss = -0.03426990285515785,
# epoch = 44, i = 500, loss = -0.021518796682357788,
# epoch = 44, i = 600, loss = -0.010509352199733257,
# epoch = 44, i = 700, loss = -0.021353445947170258,
# epoch = 44, i = 800, loss = -0.016669336706399918,
# epoch = 44, i = 900, loss = -0.030445817857980728,
# epoch = 44, i = 1000, loss = -0.06626906991004944,
# epoch = 44, i = 1100, loss = -0.013472103513777256,
# epoch = 44, i = 1200, loss = -0.058755554258823395,
# epoch = 44, i = 1300, loss = 0.004763396456837654,
# evaluating model on dev and test...
# dev_acc: 0.5136445760726929, dev_rmse: 2.680284023284912
# test_acc: 0.5322200059890747, test_rmse: 2.418553352355957
# learning rate is 0.0003180927430319355
# epoch = 45, i = 0, loss = -0.03367067128419876,
# epoch = 45, i = 100, loss = -0.025906309485435486,
# epoch = 45, i = 200, loss = -0.017301902174949646,
# epoch = 45, i = 300, loss = -0.03217636048793793,
# epoch = 45, i = 400, loss = -0.03291037678718567,
# epoch = 45, i = 500, loss = -0.02101106382906437,
# epoch = 45, i = 600, loss = -0.04000157490372658,
# epoch = 45, i = 700, loss = -0.04242445528507233,
# epoch = 45, i = 800, loss = -0.05307433381676674,
# epoch = 45, i = 900, loss = -0.018626723438501358,
# epoch = 45, i = 1000, loss = 0.02367764711380005,
# epoch = 45, i = 1100, loss = 0.0013661980628967285,
# epoch = 45, i = 1200, loss = -0.05047035589814186,
# epoch = 45, i = 1300, loss = -0.0785074457526207,
# evaluating model on dev and test...
# dev_acc: 0.5184712409973145, dev_rmse: 2.70088791847229
# test_acc: 0.538919985294342, test_rmse: 2.393449306488037
# learning rate is 0.00031491181560161616
# epoch = 46, i = 0, loss = -0.028595328330993652,
# epoch = 46, i = 100, loss = -0.01717653125524521,
# epoch = 46, i = 200, loss = -0.027322886511683464,
# epoch = 46, i = 300, loss = -0.032262589782476425,
# epoch = 46, i = 400, loss = -0.08879825472831726,
# epoch = 46, i = 500, loss = -0.0062776487320661545,
# epoch = 46, i = 600, loss = -0.033306438475847244,
# epoch = 46, i = 700, loss = -0.03380940482020378,
# epoch = 46, i = 800, loss = 0.01452363096177578,
# epoch = 46, i = 900, loss = 0.014688420109450817,
# epoch = 46, i = 1000, loss = -0.009571176022291183,
# epoch = 46, i = 1100, loss = -0.006789581850171089,
# epoch = 46, i = 1200, loss = 0.008875001221895218,
# epoch = 46, i = 1300, loss = -0.23495063185691833,
# evaluating model on dev and test...
# dev_acc: 0.5169244408607483, dev_rmse: 2.704772710800171
# test_acc: 0.5410199761390686, test_rmse: 2.407945156097412
# learning rate is 0.00031176269744559996
# epoch = 47, i = 0, loss = -0.04530283436179161,
# epoch = 47, i = 100, loss = -0.0037623653188347816,
# epoch = 47, i = 200, loss = -0.017475465312600136,
# epoch = 47, i = 300, loss = -0.1333395540714264,
# epoch = 47, i = 400, loss = -0.021067434921860695,
# epoch = 47, i = 500, loss = -0.03173699229955673,
# epoch = 47, i = 600, loss = -0.024626031517982483,
# epoch = 47, i = 700, loss = -0.04666987434029579,
# epoch = 47, i = 800, loss = -0.04341723024845123,
# epoch = 47, i = 900, loss = 0.04913855716586113,
# epoch = 47, i = 1000, loss = -0.01791244186460972,
# epoch = 47, i = 1100, loss = -0.03774551302194595,
# epoch = 47, i = 1200, loss = -0.007008685730397701,
# epoch = 47, i = 1300, loss = -0.030785921961069107,
# evaluating model on dev and test...
# dev_acc: 0.5187987089157104, dev_rmse: 2.701347589492798
# test_acc: 0.5320000052452087, test_rmse: 2.4282915592193604
# learning rate is 0.00030864507047114397
# epoch = 48, i = 0, loss = -0.02922752872109413,
# epoch = 48, i = 100, loss = -0.25067946314811707,
# epoch = 48, i = 200, loss = -0.017728349193930626,
# epoch = 48, i = 300, loss = -0.01258768979460001,
# epoch = 48, i = 400, loss = -0.022550204768776894,
# epoch = 48, i = 500, loss = -0.018735336139798164,
# epoch = 48, i = 600, loss = -0.0392734669148922,
# epoch = 48, i = 700, loss = 0.028350528329610825,
# epoch = 48, i = 800, loss = -0.6163827776908875,
# epoch = 48, i = 900, loss = -0.0254953783005476,
# epoch = 48, i = 1000, loss = -0.00019895285367965698,
# epoch = 48, i = 1100, loss = -0.05779056251049042,
# epoch = 48, i = 1200, loss = 0.06515057384967804,
# epoch = 48, i = 1300, loss = -0.005408909171819687,
# evaluating model on dev and test...
# dev_acc: 0.5155131816864014, dev_rmse: 2.7140445709228516
# test_acc: 0.5339000225067139, test_rmse: 2.4290740489959717
# learning rate is 0.0003055586197664325
# epoch = 49, i = 0, loss = -0.0793132483959198,
# epoch = 49, i = 100, loss = -0.04537378251552582,
# epoch = 49, i = 200, loss = -0.031411945819854736,
# epoch = 49, i = 300, loss = -0.030294742435216904,
# epoch = 49, i = 400, loss = -0.10245753824710846,
# epoch = 49, i = 500, loss = -0.05507668852806091,
# epoch = 49, i = 600, loss = -0.0128057561814785,
# epoch = 49, i = 700, loss = -0.027362272143363953,
# epoch = 49, i = 800, loss = -0.010500495322048664,
# epoch = 49, i = 900, loss = -0.0375492088496685,
# epoch = 49, i = 1000, loss = 0.009401572868227959,
# epoch = 49, i = 1100, loss = -0.008154720067977905,
# epoch = 49, i = 1200, loss = 0.013015622273087502,
# epoch = 49, i = 1300, loss = -0.05522759631276131,
# evaluating model on dev and test...
# dev_acc: 0.51771479845047, dev_rmse: 2.692378044128418
# test_acc: 0.5366399884223938, test_rmse: 2.3925719261169434
# learning rate is 0.0003025030335687682
# saving model..
# Done.
# epoch = 50, i = 0, loss = -0.013123036362230778,
# epoch = 50, i = 100, loss = -0.034545741975307465,
# epoch = 50, i = 200, loss = -0.04452832043170929,
# epoch = 50, i = 300, loss = 0.0052374498918652534,
# epoch = 50, i = 400, loss = -0.0786186084151268,
# epoch = 50, i = 500, loss = -0.021808184683322906,
# epoch = 50, i = 600, loss = -0.035628460347652435,
# epoch = 50, i = 700, loss = -0.05495630204677582,
# epoch = 50, i = 800, loss = 0.005000187084078789,
# epoch = 50, i = 900, loss = 0.018485277891159058,
# epoch = 50, i = 1000, loss = -0.023883283138275146,
# epoch = 50, i = 1100, loss = -0.003187349997460842,
# epoch = 50, i = 1200, loss = -0.016913481056690216,
# epoch = 50, i = 1300, loss = -0.045577965676784515,
# evaluating model on dev and test...
# dev_acc: 0.519967257976532, dev_rmse: 2.688779592514038
# test_acc: 0.5382199883460999, test_rmse: 2.38004207611084
# learning rate is 0.0002994780032330805
# epoch = 51, i = 0, loss = -0.06815768778324127,
# epoch = 51, i = 100, loss = -0.00586273055523634,
# epoch = 51, i = 200, loss = -0.025601129978895187,
# epoch = 51, i = 300, loss = 0.010304725728929043,
# epoch = 51, i = 400, loss = -0.03303326666355133,
# epoch = 51, i = 500, loss = -0.032628826797008514,
# epoch = 51, i = 600, loss = -0.00992102362215519,
# epoch = 51, i = 700, loss = -0.03400789946317673,
# epoch = 51, i = 800, loss = -0.25711214542388916,
# epoch = 51, i = 900, loss = -0.20858313143253326,
# epoch = 51, i = 1000, loss = 0.0023392587900161743,
# epoch = 51, i = 1100, loss = -0.00831985380500555,
# epoch = 51, i = 1200, loss = -0.014955725520849228,
# epoch = 51, i = 1300, loss = -0.022600095719099045,
# evaluating model on dev and test...
# dev_acc: 0.5191938877105713, dev_rmse: 2.6831469535827637
# test_acc: 0.528219997882843, test_rmse: 2.4026236534118652
# learning rate is 0.0002964832232007497
# epoch = 52, i = 0, loss = -0.278198778629303,
# epoch = 52, i = 100, loss = -0.019603267312049866,
# epoch = 52, i = 200, loss = 0.2658342123031616,
# epoch = 52, i = 300, loss = -0.04105929657816887,
# epoch = 52, i = 400, loss = -0.024948861449956894,
# epoch = 52, i = 500, loss = -0.050986845046281815,
# epoch = 52, i = 600, loss = -0.06804177910089493,
# epoch = 52, i = 700, loss = -0.015128372237086296,
# epoch = 52, i = 800, loss = 0.006379122845828533,
# epoch = 52, i = 900, loss = -0.011646397411823273,
# ...
# epoch = 82, i = 400, loss = -0.050976336002349854,
# epoch = 82, i = 500, loss = -0.008815731853246689,
# epoch = 82, i = 600, loss = -0.03404969722032547,
# epoch = 82, i = 700, loss = -0.02372567355632782,
# epoch = 82, i = 800, loss = -0.012504462152719498,
# epoch = 82, i = 900, loss = -0.02701612189412117,
# epoch = 82, i = 1000, loss = -0.05833015590906143,
# epoch = 82, i = 1100, loss = -0.018416687846183777,
# epoch = 82, i = 1200, loss = -0.02954839915037155,
# epoch = 82, i = 1300, loss = 0.006083131767809391,
# evaluating model on dev and test...
# dev_acc: 0.5237326622009277, dev_rmse: 2.669182300567627
# test_acc: 0.5386599898338318, test_rmse: 2.3905229568481445
# learning rate is 0.00021711566339590582
# epoch = 83, i = 0, loss = -0.41653338074684143,
# epoch = 83, i = 100, loss = 0.05304264649748802,
# epoch = 83, i = 200, loss = -0.01111314445734024,
# epoch = 83, i = 300, loss = -0.02552861161530018,
# epoch = 83, i = 400, loss = -0.03654424846172333,
# epoch = 83, i = 500, loss = -0.018792927265167236,
# epoch = 83, i = 600, loss = -0.03309491649270058,
# epoch = 83, i = 700, loss = -0.0012835664674639702,
# epoch = 83, i = 800, loss = 0.09439542889595032,
# epoch = 83, i = 900, loss = 0.0016331290826201439,
# epoch = 83, i = 1000, loss = -0.027904188260436058,
# epoch = 83, i = 1100, loss = 0.007686028257012367,
# epoch = 83, i = 1200, loss = 0.0064811124466359615,
# epoch = 83, i = 1300, loss = -0.02383004128932953,
# evaluating model on dev and test...
# dev_acc: 0.5204358100891113, dev_rmse: 2.6824631690979004
# test_acc: 0.5386999845504761, test_rmse: 2.410560131072998
# learning rate is 0.00021494450676194676
# epoch = 84, i = 0, loss = -0.0012244032695889473,
# epoch = 84, i = 100, loss = 0.011784030124545097,
# epoch = 84, i = 200, loss = -0.0074606239795684814,
# epoch = 84, i = 300, loss = -0.0011675190180540085,
# epoch = 84, i = 400, loss = 0.006613058503717184,
# epoch = 84, i = 500, loss = -0.0006749257445335388,
# epoch = 84, i = 600, loss = -0.010394259355962276,
# epoch = 84, i = 700, loss = 0.012483328580856323,
# epoch = 84, i = 800, loss = -0.04255792498588562,
# epoch = 84, i = 900, loss = -0.019433725625276566,
# epoch = 84, i = 1000, loss = -0.01610342040657997,
# epoch = 84, i = 1100, loss = -0.01861618645489216,
# epoch = 84, i = 1200, loss = -0.007210315205156803,
# epoch = 84, i = 1300, loss = 0.004874728620052338,
# evaluating model on dev and test...
# dev_acc: 0.5204471349716187, dev_rmse: 2.6718459129333496
# test_acc: 0.5396199822425842, test_rmse: 2.406491279602051
# learning rate is 0.0002127950616943273
# epoch = 85, i = 0, loss = -0.051414523273706436,
# epoch = 85, i = 100, loss = 0.029323484748601913,
# epoch = 85, i = 200, loss = 0.003106355667114258,
# epoch = 85, i = 300, loss = -0.03784533217549324,
# epoch = 85, i = 400, loss = -0.017613589763641357,
# epoch = 85, i = 500, loss = -0.030182335525751114,
# epoch = 85, i = 600, loss = -0.015809517353773117,
# epoch = 85, i = 700, loss = -0.021205643191933632,
# epoch = 85, i = 800, loss = -0.034764695912599564,
# epoch = 85, i = 900, loss = 0.009904974140226841,
# epoch = 85, i = 1000, loss = -0.01890639215707779,
# epoch = 85, i = 1100, loss = 0.0028698034584522247,
# epoch = 85, i = 1200, loss = -0.009845360182225704,
# epoch = 85, i = 1300, loss = -0.008666804991662502,
# evaluating model on dev and test...
# dev_acc: 0.523896336555481, dev_rmse: 2.6791884899139404
# test_acc: 0.5427600145339966, test_rmse: 2.4321184158325195
# learning rate is 0.00021066711107738402
# epoch = 86, i = 0, loss = -0.02075885236263275,
# epoch = 86, i = 100, loss = -0.05506676435470581,
# epoch = 86, i = 200, loss = -0.030040543526411057,
# epoch = 86, i = 300, loss = 0.031460240483284,
# epoch = 86, i = 400, loss = -0.03577861934900284,
# epoch = 86, i = 500, loss = -0.011002598330378532,
# epoch = 86, i = 600, loss = -0.006846907548606396,
# epoch = 86, i = 700, loss = -0.025644708424806595,
# epoch = 86, i = 800, loss = -0.02459172159433365,
# epoch = 86, i = 900, loss = -0.038922399282455444,
# epoch = 86, i = 1000, loss = -0.02197074517607689,
# epoch = 86, i = 1100, loss = -0.03794368356466293,
# epoch = 86, i = 1200, loss = 0.007421755697578192,
# epoch = 86, i = 1300, loss = -0.00597515981644392,
# evaluating model on dev and test...
# dev_acc: 0.5231455564498901, dev_rmse: 2.666653633117676
# test_acc: 0.5382999777793884, test_rmse: 2.4098963737487793
# learning rate is 0.00020856043996661018
# epoch = 87, i = 0, loss = -0.025619812309741974,
# epoch = 87, i = 100, loss = -0.04328010976314545,
# epoch = 87, i = 200, loss = -0.012986304238438606,
# epoch = 87, i = 300, loss = 0.001464271917939186,
# epoch = 87, i = 400, loss = -0.22663268446922302,
# epoch = 87, i = 500, loss = -0.00823240727186203,
# epoch = 87, i = 600, loss = -0.20125006139278412,
# epoch = 87, i = 700, loss = -0.024037551134824753,
# epoch = 87, i = 800, loss = -0.04181031137704849,
# epoch = 87, i = 900, loss = -0.13147054612636566,
# epoch = 87, i = 1000, loss = 0.005036076530814171,
# epoch = 87, i = 1100, loss = -0.02625303715467453,
# epoch = 87, i = 1200, loss = -0.04222796484827995,
# epoch = 87, i = 1300, loss = -0.03139964118599892,
# evaluating model on dev and test...
# dev_acc: 0.5238907337188721, dev_rmse: 2.670165538787842
# test_acc: 0.5424799919128418, test_rmse: 2.4485504627227783
# learning rate is 0.0002064748355669441
# epoch = 88, i = 0, loss = -0.05020776763558388,
# epoch = 88, i = 100, loss = -0.025815121829509735,
# epoch = 88, i = 200, loss = -0.019058000296354294,
# epoch = 88, i = 300, loss = -0.03143218159675598,
# epoch = 88, i = 400, loss = -0.02076171524822712,
# epoch = 88, i = 500, loss = 0.013740469701588154,
# epoch = 88, i = 600, loss = -0.01281096413731575,
# epoch = 88, i = 700, loss = -0.03575628250837326,
# epoch = 88, i = 800, loss = -0.050019241869449615,
# epoch = 88, i = 900, loss = -0.023161889985203743,
# epoch = 88, i = 1000, loss = -0.025313686579465866,
# epoch = 88, i = 1100, loss = -0.0071703605353832245,
# epoch = 88, i = 1200, loss = 0.06859567016363144,
# epoch = 88, i = 1300, loss = -0.0037142671644687653,
# evaluating model on dev and test...
# dev_acc: 0.5222535729408264, dev_rmse: 2.676447868347168
# test_acc: 0.5473399758338928, test_rmse: 2.4079036712646484
# learning rate is 0.00020441008721127464
# epoch = 89, i = 0, loss = -0.034798700362443924,
# epoch = 89, i = 100, loss = 0.032925497740507126,
# epoch = 89, i = 200, loss = -0.2191491276025772,
# epoch = 89, i = 300, loss = -0.02533886954188347,
# epoch = 89, i = 400, loss = 0.004312545992434025,
# epoch = 89, i = 500, loss = -0.10476738959550858,
# epoch = 89, i = 600, loss = 0.012717800214886665,
# epoch = 89, i = 700, loss = -0.018862659111618996,
# epoch = 89, i = 800, loss = -0.004506048746407032,
# epoch = 89, i = 900, loss = -0.04951414465904236,
# epoch = 89, i = 1000, loss = -0.025342047214508057,
# epoch = 89, i = 1100, loss = -0.03639749065041542,
# epoch = 89, i = 1200, loss = -0.0027738241478800774,
# epoch = 89, i = 1300, loss = -0.05441603064537048,
# evaluating model on dev and test...
# dev_acc: 0.5225020051002502, dev_rmse: 2.6680188179016113
# test_acc: 0.5408999919891357, test_rmse: 2.409564256668091
# learning rate is 0.0002023659863391619
# saving model..
# Done.
# epoch = 90, i = 0, loss = -0.009986776858568192,
# epoch = 90, i = 100, loss = -0.02506151795387268,
# epoch = 90, i = 200, loss = -0.007372750900685787,
# epoch = 90, i = 300, loss = -0.00892646238207817,
# epoch = 90, i = 400, loss = -0.01003983337432146,
# epoch = 90, i = 500, loss = 0.031812604516744614,
# epoch = 90, i = 600, loss = -0.004160218872129917,
# epoch = 90, i = 700, loss = -0.017328865826129913,
# epoch = 90, i = 800, loss = -0.01216797437518835,
# epoch = 90, i = 900, loss = -0.03309638798236847,
# epoch = 90, i = 1000, loss = 0.008107127621769905,
# epoch = 90, i = 1100, loss = -0.03477197512984276,
# epoch = 90, i = 1200, loss = -0.03428705036640167,
# epoch = 90, i = 1300, loss = -0.018962617963552475,
# evaluating model on dev and test...
# dev_acc: 0.5245060324668884, dev_rmse: 2.663486957550049
# test_acc: 0.5454800128936768, test_rmse: 2.406491279602051
# learning rate is 0.00020034232647577027
# epoch = 91, i = 0, loss = -0.034722987562417984,
# epoch = 91, i = 100, loss = -0.029379762709140778,
# epoch = 91, i = 200, loss = -0.0010439790785312653,
# epoch = 91, i = 300, loss = -0.03980126231908798,
# epoch = 91, i = 400, loss = -0.008093799464404583,
# epoch = 91, i = 500, loss = -0.021422797814011574,
# epoch = 91, i = 600, loss = -0.007153894752264023,
# epoch = 91, i = 700, loss = -0.02025679312646389,
# epoch = 91, i = 800, loss = -0.10034210979938507,
# epoch = 91, i = 900, loss = -0.01763564720749855,
# epoch = 91, i = 1000, loss = -0.05648138374090195,
# epoch = 91, i = 1100, loss = 0.009074229747056961,
# epoch = 91, i = 1200, loss = -0.05065380036830902,
# epoch = 91, i = 1300, loss = -0.040862731635570526,
# evaluating model on dev and test...
# dev_acc: 0.5251213908195496, dev_rmse: 2.6785037517547607
# test_acc: 0.5414999723434448, test_rmse: 2.406200408935547
# learning rate is 0.00019833890321101254
# epoch = 92, i = 0, loss = -0.03714611381292343,
# epoch = 92, i = 100, loss = 0.00032517407089471817,
# epoch = 92, i = 200, loss = 0.010322603397071362,
# epoch = 92, i = 300, loss = -0.15317194163799286,
# epoch = 92, i = 400, loss = 0.02329959347844124,
# epoch = 92, i = 500, loss = -0.036776598542928696,
# epoch = 92, i = 600, loss = -0.006171189248561859,
# epoch = 92, i = 700, loss = -0.016369706019759178,
# epoch = 92, i = 800, loss = -0.03490867838263512,
# epoch = 92, i = 900, loss = 0.0009636087343096733,
# epoch = 92, i = 1000, loss = 0.012013890780508518,
# epoch = 92, i = 1100, loss = -0.031543001532554626,
# epoch = 92, i = 1200, loss = -0.02605307102203369,
# epoch = 92, i = 1300, loss = -0.06828704476356506,
# evaluating model on dev and test...
# dev_acc: 0.5236818194389343, dev_rmse: 2.660740852355957
# test_acc: 0.5443400144577026, test_rmse: 2.425572156906128
# learning rate is 0.00019635551417890244
# epoch = 93, i = 0, loss = -0.014079329557716846,
# epoch = 93, i = 100, loss = -0.0017892587929964066,
# epoch = 93, i = 200, loss = -0.05503726378083229,
# epoch = 93, i = 300, loss = -0.009165873751044273,
# epoch = 93, i = 400, loss = -0.0001729615032672882,
# epoch = 93, i = 500, loss = -0.03371560946106911,
# epoch = 93, i = 600, loss = -0.03259792923927307,
# epoch = 93, i = 700, loss = -0.009977656416594982,
# epoch = 93, i = 800, loss = -0.01057853177189827,
# epoch = 93, i = 900, loss = -0.018096748739480972,
# epoch = 93, i = 1000, loss = -0.012886350043118,
# epoch = 93, i = 1100, loss = 0.00882323645055294,
# epoch = 93, i = 1200, loss = -0.007390306331217289,
# epoch = 93, i = 1300, loss = -0.03893579542636871,
# evaluating model on dev and test...
# dev_acc: 0.5248842835426331, dev_rmse: 2.672806978225708
# test_acc: 0.5384399890899658, test_rmse: 2.4130892753601074
# learning rate is 0.0001943919590371134
# epoch = 94, i = 0, loss = 0.007771260105073452,
# epoch = 94, i = 100, loss = -0.0203685462474823,
# epoch = 94, i = 200, loss = 0.009952259249985218,
# epoch = 94, i = 300, loss = -0.032206941395998,
# epoch = 94, i = 400, loss = 0.010489375330507755,
# epoch = 94, i = 500, loss = -0.03385665640234947,
# epoch = 94, i = 600, loss = -0.03692160174250603,
# epoch = 94, i = 700, loss = -0.03695817291736603,
# epoch = 94, i = 800, loss = -0.30590128898620605,
# epoch = 94, i = 900, loss = 0.0574871227145195,
# epoch = 94, i = 1000, loss = -0.019390389323234558,
# epoch = 94, i = 1100, loss = -0.007786057889461517,
# epoch = 94, i = 1200, loss = -0.06390387564897537,
# epoch = 94, i = 1300, loss = -0.02297619730234146,
# evaluating model on dev and test...
# dev_acc: 0.5273569226264954, dev_rmse: 2.665616273880005
# test_acc: 0.5444400310516357, test_rmse: 2.402540445327759
# learning rate is 0.00019244803944674227
# epoch = 95, i = 0, loss = 0.015355472452938557,
# epoch = 95, i = 100, loss = -0.005087569355964661,
# epoch = 95, i = 200, loss = 0.008777452632784843,
# epoch = 95, i = 300, loss = 0.027054689824581146,
# epoch = 95, i = 400, loss = -0.019572973251342773,
# epoch = 95, i = 500, loss = 0.012728395871818066,
# epoch = 95, i = 600, loss = 0.0033571142703294754,
# epoch = 95, i = 700, loss = -0.007821789011359215,
# epoch = 95, i = 800, loss = 0.0049156369641423225,
# epoch = 95, i = 900, loss = -0.07431020587682724,
# epoch = 95, i = 1000, loss = -0.04359988868236542,
# epoch = 95, i = 1100, loss = 0.03004167228937149,
# epoch = 95, i = 1200, loss = -0.01752365753054619,
# epoch = 95, i = 1300, loss = 0.021890267729759216,
# evaluating model on dev and test...
# dev_acc: 0.5238907337188721, dev_rmse: 2.661228656768799
# test_acc: 0.5451599955558777, test_rmse: 2.39365816116333
# learning rate is 0.00019052355905227483
# epoch = 96, i = 0, loss = -0.01056450605392456,
# epoch = 96, i = 100, loss = -0.017363887280225754,
# epoch = 96, i = 200, loss = -0.016631919890642166,
# epoch = 96, i = 300, loss = -0.03322049602866173,
# epoch = 96, i = 400, loss = 0.008932400494813919,
# epoch = 96, i = 500, loss = -0.008603227324783802,
# epoch = 96, i = 600, loss = -0.04532424733042717,
# epoch = 96, i = 700, loss = -0.06113220006227493,
# epoch = 96, i = 800, loss = -0.05451664701104164,
# epoch = 96, i = 900, loss = -0.030624687671661377,
# epoch = 96, i = 1000, loss = -0.0012704720720648766,
# epoch = 96, i = 1100, loss = 0.20633617043495178,
# epoch = 96, i = 1200, loss = 0.009965821169316769,
# epoch = 96, i = 1300, loss = 0.0020279083400964737,
# evaluating model on dev and test...
# dev_acc: 0.5219374299049377, dev_rmse: 2.6718037128448486
# test_acc: 0.5440400242805481, test_rmse: 2.3962888717651367
# learning rate is 0.00018861832346175208
# epoch = 97, i = 0, loss = -0.014056106097996235,
# epoch = 97, i = 100, loss = -0.00854018796235323,
# epoch = 97, i = 200, loss = -0.5969178676605225,
# epoch = 97, i = 300, loss = -0.0037707332521677017,
# epoch = 97, i = 400, loss = 0.02102772705256939,
# epoch = 97, i = 500, loss = -0.01454025786370039,
# epoch = 97, i = 600, loss = -0.013207705691456795,
# epoch = 97, i = 700, loss = -0.04692085459828377,
# epoch = 97, i = 800, loss = -0.0019707651808857918,
# epoch = 97, i = 900, loss = -0.009007718414068222,
# epoch = 97, i = 1000, loss = -0.013208543881773949,
# epoch = 97, i = 1100, loss = -0.06281265616416931,
# epoch = 97, i = 1200, loss = -0.004619048908352852,
# epoch = 97, i = 1300, loss = -0.259182870388031,
# evaluating model on dev and test...
# dev_acc: 0.524161696434021, dev_rmse: 2.6645781993865967
# test_acc: 0.5424200296401978, test_rmse: 2.394243001937866
# learning rate is 0.0001867321402271346
# epoch = 98, i = 0, loss = -0.0023030219599604607,
# epoch = 98, i = 100, loss = -0.013036379590630531,
# epoch = 98, i = 200, loss = -0.028199488297104836,
# epoch = 98, i = 300, loss = 0.01392904482781887,
# epoch = 98, i = 400, loss = -0.033134277909994125,
# epoch = 98, i = 500, loss = -0.4112471044063568,
# epoch = 98, i = 600, loss = -0.021515771746635437,
# epoch = 98, i = 700, loss = -0.027042727917432785,
# epoch = 98, i = 800, loss = 0.004821453243494034,
# epoch = 98, i = 900, loss = -0.05139495059847832,
# epoch = 98, i = 1000, loss = 0.005275981035083532,
# epoch = 98, i = 1100, loss = -0.02899571880698204,
# epoch = 98, i = 1200, loss = -0.01388679351657629,
# epoch = 98, i = 1300, loss = -0.04538160189986229,
# evaluating model on dev and test...
# dev_acc: 0.5243988037109375, dev_rmse: 2.6662304401397705
# test_acc: 0.5438399910926819, test_rmse: 2.404620409011841
# learning rate is 0.00018486481882486322
# epoch = 99, i = 0, loss = 0.007194642908871174,
# epoch = 99, i = 100, loss = -0.005698900669813156,
# epoch = 99, i = 200, loss = -0.03454482927918434,
# epoch = 99, i = 300, loss = -0.02821585163474083,
# epoch = 99, i = 400, loss = -0.013555953279137611,
# epoch = 99, i = 500, loss = -0.044967882335186005,
# epoch = 99, i = 600, loss = -0.03993823379278183,
# epoch = 99, i = 700, loss = -0.021089058369398117,
# epoch = 99, i = 800, loss = 0.0032024532556533813,
# epoch = 99, i = 900, loss = -0.007227159105241299,
# epoch = 99, i = 1000, loss = 0.022763043642044067,
# epoch = 99, i = 1100, loss = -0.011412052437663078,
# epoch = 99, i = 1200, loss = -0.05225127190351486,
# epoch = 99, i = 1300, loss = -0.007169637829065323,
# evaluating model on dev and test...
# dev_acc: 0.522321343421936, dev_rmse: 2.668008327484131
# test_acc: 0.5412800312042236, test_rmse: 2.3916940689086914

# %%
model.eval()
dev_acc, dev_rmse = evaluate(model, hmqa_dev_loader)
print("dev_acc: {}, dev_rmse: {}".format(dev_acc, dev_rmse))
test_acc, test_rmse = evaluate(model, hmqa_test_loader)
print("test_acc: {}, test_rmse: {}".format(test_acc, test_rmse))
model.train()
None
# Out:
# dev_acc: 0.5313029289245605, dev_rmse: 2.665912628173828
# test_acc: 0.541100025177002, test_rmse: 2.416609287261963

# %%
train_acc, train_rmse = evaluate(model, hmqa_train_loader)
train_acc, train_rmse
# Out:
# (tensor(0.7304), tensor(1.2511))

# %%
torch.save(model.state_dict(), "./saved_models/hope-epoch-99-acc")

# %%
len(test_accs), len(dev_accs)
# Out:
# (100, 100)

# %%
top_dev_accs = sorted(zip(dev_accs, test_accs, test_rmses), reverse=True)
top_dev_accs
# Out:
# [(tensor(0.5274), tensor(0.5444), tensor(2.4025)),
#  (tensor(0.5271), tensor(0.5389), tensor(2.4144)),
#  (tensor(0.5252), tensor(0.5374), tensor(2.3979)),
#  (tensor(0.5251), tensor(0.5415), tensor(2.4062)),
#  (tensor(0.5249), tensor(0.5384), tensor(2.4131)),
#  (tensor(0.5245), tensor(0.5455), tensor(2.4065)),
#  (tensor(0.5245), tensor(0.5361), tensor(2.3854)),
#  (tensor(0.5245), tensor(0.5396), tensor(2.4072)),
#  (tensor(0.5244), tensor(0.5438), tensor(2.4046)),
#  (tensor(0.5242), tensor(0.5387), tensor(2.4005)),
#  (tensor(0.5242), tensor(0.5372), tensor(2.4016)),
#  (tensor(0.5242), tensor(0.5424), tensor(2.3942)),
#  (tensor(0.5241), tensor(0.5408), tensor(2.3845)),
#  (tensor(0.5239), tensor(0.5345), tensor(2.3803)),
#  (tensor(0.5239), tensor(0.5428), tensor(2.4321)),
#  (tensor(0.5239), tensor(0.5452), tensor(2.3937)),
#  (tensor(0.5239), tensor(0.5425), tensor(2.4486)),
#  (tensor(0.5237), tensor(0.5387), tensor(2.3905)),
#  (tensor(0.5237), tensor(0.5425), tensor(2.4173)),
#  (tensor(0.5237), tensor(0.5443), tensor(2.4256)),
#  (tensor(0.5237), tensor(0.5378), tensor(2.4545)),
#  (tensor(0.5236), tensor(0.5406), tensor(2.3896)),
#  (tensor(0.5235), tensor(0.5384), tensor(2.4110)),
#  (tensor(0.5232), tensor(0.5391), tensor(2.3999)),
#  (tensor(0.5231), tensor(0.5383), tensor(2.4099)),
#  (tensor(0.5225), tensor(0.5409), tensor(2.4096)),
#  (tensor(0.5224), tensor(0.5317), tensor(2.3987)),
#  (tensor(0.5224), tensor(0.5367), tensor(2.3958)),
#  (tensor(0.5223), tensor(0.5413), tensor(2.3917)),
#  (tensor(0.5223), tensor(0.5473), tensor(2.4079)),
#  (tensor(0.5219), tensor(0.5440), tensor(2.3963)),
#  (tensor(0.5217), tensor(0.5407), tensor(2.4173)),
#  (tensor(0.5216), tensor(0.5377), tensor(2.4054)),
#  (tensor(0.5214), tensor(0.5374), tensor(2.4014)),
#  (tensor(0.5213), tensor(0.5365), tensor(2.4005)),
#  (tensor(0.5212), tensor(0.5294), tensor(2.4417)),
#  (tensor(0.5211), tensor(0.5361), tensor(2.4331)),
#  (tensor(0.5209), tensor(0.5452), tensor(2.4083)),
#  (tensor(0.5207), tensor(0.5369), tensor(2.3912)),
#  (tensor(0.5205), tensor(0.5361), tensor(2.4057)),
#  (tensor(0.5205), tensor(0.5338), tensor(2.3943)),
#  (tensor(0.5204), tensor(0.5396), tensor(2.4065)),
#  (tensor(0.5204), tensor(0.5387), tensor(2.4106)),
#  (tensor(0.5202), tensor(0.5293), tensor(2.4095)),
#  (tensor(0.5200), tensor(0.5359), tensor(2.3941)),
#  (tensor(0.5200), tensor(0.5382), tensor(2.3800)),
#  (tensor(0.5199), tensor(0.5344), tensor(2.4277)),
#  (tensor(0.5192), tensor(0.5282), tensor(2.4026)),
#  (tensor(0.5191), tensor(0.5300), tensor(2.3888)),
#  (tensor(0.5188), tensor(0.5320), tensor(2.4283)),
#  (tensor(0.5185), tensor(0.5389), tensor(2.3934)),
#  (tensor(0.5184), tensor(0.5368), tensor(2.4274)),
#  (tensor(0.5177), tensor(0.5366), tensor(2.3926)),
#  (tensor(0.5169), tensor(0.5410), tensor(2.4079)),
#  (tensor(0.5161), tensor(0.5261), tensor(2.4109)),
#  (tensor(0.5155), tensor(0.5339), tensor(2.4291)),
#  (tensor(0.5149), tensor(0.5286), tensor(2.4377)),
#  (tensor(0.5139), tensor(0.5312), tensor(2.4431)),
#  (tensor(0.5136), tensor(0.5322), tensor(2.4186)),
#  (tensor(0.5132), tensor(0.5286), tensor(2.4175)),
#  (tensor(0.5128), tensor(0.5295), tensor(2.4524)),
#  (tensor(0.5124), tensor(0.5319), tensor(2.4059)),
#  (tensor(0.5123), tensor(0.5301), tensor(2.4561)),
#  (tensor(0.5122), tensor(0.5346), tensor(2.4454)),
#  (tensor(0.5122), tensor(0.5264), tensor(2.4320)),
#  (tensor(0.5119), tensor(0.5328), tensor(2.4236)),
#  (tensor(0.5116), tensor(0.5258), tensor(2.4550)),
#  (tensor(0.5116), tensor(0.5295), tensor(2.4493)),
#  (tensor(0.5111), tensor(0.5315), tensor(2.4629)),
#  (tensor(0.5109), tensor(0.5281), tensor(2.4224)),
#  (tensor(0.5095), tensor(0.5277), tensor(2.4490)),
#  (tensor(0.5090), tensor(0.5290), tensor(2.4434)),
#  (tensor(0.5083), tensor(0.5281), tensor(2.4781)),
#  (tensor(0.5065), tensor(0.5185), tensor(2.4891)),
#  (tensor(0.5060), tensor(0.5251), tensor(2.4278)),
#  (tensor(0.5059), tensor(0.5291), tensor(2.4695)),
#  (tensor(0.5049), tensor(0.5184), tensor(2.4482)),
#  (tensor(0.5048), tensor(0.5279), tensor(2.4275)),
#  (tensor(0.5047), tensor(0.5184), tensor(2.4335)),
#  (tensor(0.5031), tensor(0.5157), tensor(2.4287)),
#  (tensor(0.5021), tensor(0.5179), tensor(2.4748)),
#  (tensor(0.5012), tensor(0.5186), tensor(2.4638)),
#  (tensor(0.5000), tensor(0.5158), tensor(2.4179)),
#  (tensor(0.4999), tensor(0.5156), tensor(2.4377)),
#  (tensor(0.4979), tensor(0.5137), tensor(2.5062)),
#  (tensor(0.4934), tensor(0.5066), tensor(2.5333)),
#  (tensor(0.4931), tensor(0.5014), tensor(2.5268)),
#  (tensor(0.4919), tensor(0.5086), tensor(2.4420)),
#  (tensor(0.4912), tensor(0.5040), tensor(2.5028)),
#  (tensor(0.4870), tensor(0.4969), tensor(2.5466)),
#  (tensor(0.4851), tensor(0.4925), tensor(2.5593)),
#  (tensor(0.4840), tensor(0.4895), tensor(2.5219)),
#  (tensor(0.4744), tensor(0.4831), tensor(2.5449)),
#  (tensor(0.4728), tensor(0.4803), tensor(2.6100)),
#  (tensor(0.4663), tensor(0.4711), tensor(2.6475)),
#  (tensor(0.4575), tensor(0.4606), tensor(2.7094)),
#  (tensor(0.4462), tensor(0.4457), tensor(2.6801)),
#  (tensor(0.4342), tensor(0.4325), tensor(2.7651)),
#  (tensor(0.4265), tensor(0.4191), tensor(2.8297)),
#  (tensor(0.3995), tensor(0.3989), tensor(3.0767))]

# %%
best_dev_acc, corr_test_acc, corr_test_rmse = top_dev_accs[0]
print("The best dev accuracy is {}. The corresponding test accuracy and test RMSE are {} and {} respectively".format(
    best_dev_acc, corr_test_acc, corr_test_rmse
))
